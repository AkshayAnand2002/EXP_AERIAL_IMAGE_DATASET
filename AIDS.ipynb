# %%
# !pip install opendatasets --upgrade --quiet
# !pip install kaggle --quiet

# Import required libraries
import opendatasets as od
import os
import cv2
import numpy as np
from keras.preprocessing.image import img_to_array
from sklearn.preprocessing import LabelBinarizer
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
from keras.callbacks import LearningRateScheduler
from keras.optimizers import SGD
from keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout, Input
from keras.models import Model
import tensorflow as tf
from sklearn.metrics import f1_score, accuracy_score, precision_score, recall_score, classification_report
import time

# Download dataset from Kaggle
dataset_url = 'https://www.kaggle.com/datasets/jiayuanchengala/aid-scene-classification-datasets'
od.download(dataset_url)

# Set the path to the image folder
data_path = 'aid-scene-classification-datasets/AID'

# Load and preprocess dataset
image_data = []
labels = []

for root, dirs, files in os.walk(data_path):
    for file in files:
        if file.endswith(".jpg"):
            image = cv2.imread(os.path.join(root, file))
            image = cv2.resize(image, (32, 32))
            image = img_to_array(image)
            image_data.append(image)
            label = root.split(os.path.sep)[-1]
            labels.append(label)

image_data = np.array(image_data, dtype="float") / 255.0
labels = np.array(labels)

lb = LabelBinarizer()
labels = lb.fit_transform(labels)

x_train, x_test, y_train, y_test = train_test_split(image_data, labels, test_size=0.2, random_state=42)
print(f'Training samples: {len(x_train)}, Testing samples: {len(x_test)}')

# Define Teacher Model
def teacher_model(input_shape, num_classes):
    inputs = Input(shape=input_shape)
    x = Conv2D(64, (3, 3), activation='relu', padding='same')(inputs)
    x = MaxPooling2D((2, 2))(x)
    x = Conv2D(128, (3, 3), activation='relu', padding='same')(x)
    x = MaxPooling2D((2, 2))(x)
    x = Conv2D(256, (3, 3), activation='relu', padding='same')(x)
    x = MaxPooling2D((2, 2))(x)
    x = Conv2D(512, (3, 3), activation='relu', padding='same')(x)
    x = MaxPooling2D((2, 2))(x)
    x = Flatten()(x)
    x = Dense(512, activation='relu')(x)
    x = Dropout(0.5)(x)
    outputs = Dense(num_classes, activation='softmax')(x)
    return Model(inputs, outputs)

# Define Student Model
def student_model(input_shape, num_classes):
    inputs = Input(shape=input_shape)
    x = Conv2D(32, (3, 3), activation='relu', padding='same')(inputs)
    x = MaxPooling2D((2, 2))(x)
    x = Conv2D(64, (3, 3), activation='relu', padding='same')(x)
    x = MaxPooling2D((2, 2))(x)
    x = Conv2D(128, (3, 3), activation='relu', padding='same')(x)
    x = MaxPooling2D((2, 2))(x)
    x = Flatten()(x)
    x = Dense(256, activation='relu')(x)
    x = Dropout(0.5)(x)
    outputs = Dense(num_classes, activation='softmax')(x)
    return Model(inputs, outputs)

input_shape = (32, 32, 3)
num_classes = len(lb.classes_)

teacher = teacher_model(input_shape, num_classes)
student = student_model(input_shape, num_classes)

# Learning rate scheduler
def lr_scheduler(epoch, lr):
    return float(lr * tf.math.exp(-0.1)) if epoch >= 10 else float(lr)

# Train Teacher
teacher.compile(optimizer=SGD(learning_rate=1e-2, momentum=0.9), loss='categorical_crossentropy', metrics=['accuracy'])
teacher.fit(x_train, y_train, batch_size=32, epochs=15, validation_data=(x_test, y_test), callbacks=[LearningRateScheduler(lr_scheduler)])

# Teacher Evaluation
teacher_score = teacher.evaluate(x_test, y_test, verbose=0)
print(f'Teacher test accuracy: {teacher_score[1] * 100:.2f}%')

# Teacher predictions (for distillation)
teacher_preds = teacher.predict(x_train)

# Distillation Loss Function (alpha=0.25)
def distillation_loss(y_true, y_pred, teacher_preds, temperature=3.0, alpha=0.25):
    teacher_batch_preds = tf.gather(teacher_preds, tf.range(tf.shape(y_pred)[0]))
    y_true_soft = tf.keras.activations.softmax(y_true / temperature)
    y_pred_soft = tf.keras.activations.softmax(y_pred / temperature)
    teacher_soft = tf.keras.activations.softmax(teacher_batch_preds / temperature)
    soft_loss = tf.keras.losses.categorical_crossentropy(teacher_soft, y_pred_soft)
    hard_loss = tf.keras.losses.categorical_crossentropy(y_true_soft, y_pred_soft)
    return alpha * soft_loss + (1. - alpha) * hard_loss

# Train Student
student.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=1e-3),
    loss=lambda y_true, y_pred: distillation_loss(y_true, y_pred, teacher_preds),
    metrics=['accuracy']
)
student.fit(x_train, y_train, batch_size=32, epochs=30, validation_data=(x_test, y_test), callbacks=[LearningRateScheduler(lr_scheduler)])

# Save trained models
teacher.save("teacher_model.h5")
student.save("student_model.h5")
print("Models saved successfully.")

# Evaluate Student on Clean Test Set
start_time = time.time()
y_pred_probs = student.predict(x_test)
inference_time = time.time() - start_time

y_pred = np.argmax(y_pred_probs, axis=1)
y_true = np.argmax(y_test, axis=1)

print("\n=== Final Student Model Evaluation on Clean Test Set ===")
print(classification_report(y_true, y_pred, target_names=lb.classes_))
print(f"Inference Time: {inference_time:.4f} seconds")

# -----------------------------
# Robustness Evaluation Against Gaussian Noise
# -----------------------------

y_reference_probs = student.predict(x_test)
y_reference = np.argmax(y_reference_probs, axis=1)

# Lists to store results
stddev_values = np.linspace(0, 1, 20)
noisy_accuracies, noisy_f1_scores, noisy_precisions, noisy_recalls = [], [], [], []
y_reference_list = []
y_reference_probs_list = []
y_pred_noisy_probs_list = []
y_pred_noisy_list = []

for stddev in stddev_values:
    noise = np.random.normal(loc=0.0, scale=stddev, size=x_test.shape)
    x_noisy = np.clip(x_test + noise, 0., 1.)

    y_pred_noisy_probs = student.predict(x_noisy)
    y_pred_noisy = np.argmax(y_pred_noisy_probs, axis=1)

    acc = accuracy_score(y_reference, y_pred_noisy)
    f1 = f1_score(y_reference, y_pred_noisy, average='weighted')
    precision = precision_score(y_reference, y_pred_noisy, average='weighted')
    recall = recall_score(y_reference, y_pred_noisy, average='weighted')

    noisy_accuracies.append(acc)
    noisy_f1_scores.append(f1)
    noisy_precisions.append(precision)
    noisy_recalls.append(recall)

    # Store predictions and references
    y_reference_list.append(y_reference)
    y_reference_probs_list.append(y_reference_probs)
    y_pred_noisy_probs_list.append(y_pred_noisy_probs)
    y_pred_noisy_list.append(y_pred_noisy)

    print(f"Noise STDDEV = {stddev:.2f} -> Accuracy = {acc:.4f}, F1 = {f1:.4f}, Precision = {precision:.4f}, Recall = {recall:.4f}")
# Out:
# Please provide your Kaggle credentials to download this dataset. Learn more: http://bit.ly/kaggle-creds
# Your Kaggle username:Your Kaggle Key:Dataset URL: https://www.kaggle.com/datasets/jiayuanchengala/aid-scene-classification-datasets
# Downloading aid-scene-classification-datasets.zip to ./aid-scene-classification-datasets
# 100%|██████████| 2.45G/2.45G [00:25<00:00, 102MB/s]
# Training samples: 8000, Testing samples: 2000
# Epoch 1/15
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 105s 415ms/step - accuracy: 0.0499 - loss: 3.3501 - val_accuracy: 0.0915 - val_loss: 3.0202 - learning_rate: 0.0100
# Epoch 2/15
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 144s 423ms/step - accuracy: 0.1645 - loss: 2.8070 - val_accuracy: 0.2810 - val_loss: 2.3634 - learning_rate: 0.0100
# Epoch 3/15
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 104s 417ms/step - accuracy: 0.2905 - loss: 2.3374 - val_accuracy: 0.3780 - val_loss: 2.0281 - learning_rate: 0.0100
# Epoch 4/15
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 147s 436ms/step - accuracy: 0.3844 - loss: 2.0459 - val_accuracy: 0.4640 - val_loss: 1.8056 - learning_rate: 0.0100
# Epoch 5/15
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 109s 436ms/step - accuracy: 0.4467 - loss: 1.7948 - val_accuracy: 0.4770 - val_loss: 1.7114 - learning_rate: 0.0100
# Epoch 6/15
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 136s 410ms/step - accuracy: 0.4879 - loss: 1.6542 - val_accuracy: 0.4600 - val_loss: 1.8414 - learning_rate: 0.0100
# Epoch 7/15
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 107s 429ms/step - accuracy: 0.5096 - loss: 1.5598 - val_accuracy: 0.5115 - val_loss: 1.5654 - learning_rate: 0.0100
# Epoch 8/15
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 105s 420ms/step - accuracy: 0.5566 - loss: 1.4043 - val_accuracy: 0.5450 - val_loss: 1.4633 - learning_rate: 0.0100
# Epoch 9/15
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 105s 419ms/step - accuracy: 0.6172 - loss: 1.2395 - val_accuracy: 0.5645 - val_loss: 1.4609 - learning_rate: 0.0100
# Epoch 10/15
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 140s 411ms/step - accuracy: 0.6350 - loss: 1.1561 - val_accuracy: 0.5640 - val_loss: 1.4214 - learning_rate: 0.0100
# Epoch 11/15
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 143s 415ms/step - accuracy: 0.6662 - loss: 1.0452 - val_accuracy: 0.5815 - val_loss: 1.3826 - learning_rate: 0.0090
# Epoch 12/15
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 141s 412ms/step - accuracy: 0.7218 - loss: 0.8790 - val_accuracy: 0.6160 - val_loss: 1.3560 - learning_rate: 0.0082
# Epoch 13/15
# 250/250 ━━━━━━━━━━━━━━━━━━━━
# Epoch 22/30
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 41s 104ms/step - accuracy: 0.8463 - loss: 3.4003 - val_accuracy: 0.6635 - val_loss: 3.4005 - learning_rate: 3.0119e-04
# Epoch 23/30
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 25s 100ms/step - accuracy: 0.8578 - loss: 3.4002 - val_accuracy: 0.6625 - val_loss: 3.4006 - learning_rate: 2.7253e-04
# Epoch 24/30
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 41s 100ms/step - accuracy: 0.8584 - loss: 3.4002 - val_accuracy: 0.6685 - val_loss: 3.4005 - learning_rate: 2.4660e-04
# Epoch 25/30
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 42s 104ms/step - accuracy: 0.8776 - loss: 3.4002 - val_accuracy: 0.6610 - val_loss: 3.4006 - learning_rate: 2.2313e-04
# Epoch 26/30
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 40s 99ms/step - accuracy: 0.8827 - loss: 3.4002 - val_accuracy: 0.6670 - val_loss: 3.4005 - learning_rate: 2.0190e-04
# Epoch 27/30
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 42s 103ms/step - accuracy: 0.8737 - loss: 3.4002 - val_accuracy: 0.6585 - val_loss: 3.4006 - learning_rate: 1.8268e-04
# Epoch 28/30
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 25s 98ms/step - accuracy: 0.8894 - loss: 3.4002 - val_accuracy: 0.6615 - val_loss: 3.4006 - learning_rate: 1.6530e-04
# Epoch 29/30
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 25s 99ms/step - accuracy: 0.8964 - loss: 3.4002 - val_accuracy: 0.6630 - val_loss: 3.4006 - learning_rate: 1.4957e-04
# Epoch 30/30
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 42s 102ms/step - accuracy: 0.8983 - loss: 3.4002 - val_accuracy: 0.6580 - val_loss: 3.4006 - learning_rate: 1.3534e-04
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Models saved successfully.
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step
#
# === Final Student Model Evaluation on Clean Test Set ===
#                    precision    recall  f1-score   support
#
#           Airport       0.57      0.58      0.58        77
#          BareLand       0.79      0.81      0.80        59
#     BaseballField       0.88      0.86      0.87        42
#             Beach       0.87      0.89      0.88        80
#            Bridge       0.89      0.79      0.84        63
#            Center       0.66      0.61      0.63        54
#            Church       0.65      0.58      0.61        52
#        Commercial       0.51      0.49      0.50        88
#  DenseResidential       0.57      0.84      0.68        86
#            Desert       0.82      0.86      0.84        59
#          Farmland       0.71      0.67      0.69        78
#            Forest       0.88      0.93      0.90        40
#        Industrial       0.42      0.46      0.44        85
#            Meadow       0.90      0.85      0.87        52
# MediumResidential       0.64      0.57      0.60        56
#          Mountain       0.56      0.51      0.53        68
#              Park       0.65      0.56      0.60        81
#           Parking       0.87      0.76      0.81        80
#        Playground       0.79      0.90      0.84        58
#              Pond       0.85      0.80      0.83        80
#              Port       0.84      0.77      0.81        84
#    RailwayStation       0.52      0.50      0.51        54
#            Resort       0.49      0.41      0.45        61
#             River       0.57      0.53      0.55        73
#            School       0.29      0.28      0.28        58
# SparseResidential       0.90      0.79      0.84        66
#            Square       0.42      0.41      0.41        66
#           Stadium       0.84      0.93      0.88        55
#      StorageTanks       0.54      0.54      0.54        71
#           Viaduct       0.35      0.49      0.40        74
#
#          accuracy                           0.66      2000
#         macro avg       0.67      0.67      0.67      2000
#      weighted avg       0.67      0.66      0.66      2000
#
# Inference Time: 2.6694 seconds
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step
# Noise STDDEV = 0.00 -> Accuracy = 1.0000, F1 = 1.0000, Precision = 1.0000, Recall = 1.0000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 2s 34ms/step
# Noise STDDEV = 0.05 -> Accuracy = 0.7920, F1 = 0.7907, Precision = 0.8178, Recall = 0.7920
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step
# Noise STDDEV = 0.11 -> Accuracy = 0.5155, F1 = 0.4966, Precision = 0.6423, Recall = 0.5155
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step
# Noise STDDEV = 0.16 -> Accuracy = 0.3380, F1 = 0.2984, Precision = 0.4488, Recall = 0.3380
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step
# Noise STDDEV = 0.21 -> Accuracy = 0.2345, F1 = 0.1931, Precision = 0.3782, Recall = 0.2345
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# Noise STDDEV = 0.26 -> Accuracy = 0.1880, F1 = 0.1444, Precision = 0.3262, Recall = 0.1880
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 2s 36ms/step
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# Noise STDDEV = 0.32 -> Accuracy = 0.1475, F1 = 0.1074, Precision = 0.2807, Recall = 0.1475
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 2s 23ms/step
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# Noise STDDEV = 0.37 -> Accuracy = 0.1195, F1 = 0.0802, Precision = 0.1333, Recall = 0.1195
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step
# Noise STDDEV = 0.42 -> Accuracy = 0.0890, F1 = 0.0554, Precision = 0.1525, Recall = 0.0890
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step
# Noise STDDEV = 0.47 -> Accuracy = 0.0865, F1 = 0.0461, Precision = 0.1483, Recall = 0.0865
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step
# Noise STDDEV = 0.53 -> Accuracy = 0.0655, F1 = 0.0334, Precision = 0.0698, Recall = 0.0655
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# Noise STDDEV = 0.58 -> Accuracy = 0.0675, F1 = 0.0354, Precision = 0.1009, Recall = 0.0675
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 2s 29ms/step
# Noise STDDEV = 0.63 -> Accuracy = 0.0665, F1 = 0.0320, Precision = 0.0665, Recall = 0.0665
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# Noise STDDEV = 0.68 -> Accuracy = 0.0565, F1 = 0.0242, Precision = 0.0519, Recall = 0.0565
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# Noise STDDEV = 0.74 -> Accuracy = 0.0505, F1 = 0.0179, Precision = 0.0126, Recall = 0.0505
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step
# Noise STDDEV = 0.79 -> Accuracy = 0.0490, F1 = 0.0173, Precision = 0.0183, Recall = 0.0490
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 2s 28ms/step
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# Noise STDDEV = 0.84 -> Accuracy = 0.0525, F1 = 0.0191, Precision = 0.0463, Recall = 0.0525
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# Noise STDDEV = 0.89 -> Accuracy = 0.0455, F1 = 0.0148, Precision = 0.0114, Recall = 0.0455
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# Noise STDDEV = 0.95 -> Accuracy = 0.0495, F1 = 0.0176, Precision = 0.0143, Recall = 0.0495
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step
# Noise STDDEV = 1.00 -> Accuracy = 0.0405, F1 = 0.0124, Precision = 0.0084, Recall = 0.0405
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))

# %%
print(y_reference_list)
print(y_reference_probs_list)
print(y_pred_noisy_probs_list)
print(y_pred_noisy_list)
# Out:
# [array([ 5, 27, 28, ..., 27, 29,  3]), array([ 5, 27, 28, ..., 27, 29,  3]), array([ 5, 27, 28, ..., 27, 29,  3]), array([ 5, 27, 28, ..., 27, 29,  3]), array([ 5, 27, 28, ..., 27, 29,  3]), array([ 5, 27, 28, ..., 27, 29,  3]), array([ 5, 27, 28, ..., 27, 29,  3]), array([ 5, 27, 28, ..., 27, 29,  3]), array([ 5, 27, 28, ..., 27, 29,  3]), array([ 5, 27, 28, ..., 27, 29,  3]), array([ 5, 27, 28, ..., 27, 29,  3]), array([ 5, 27, 28, ..., 27, 29,  3]), array([ 5, 27, 28, ..., 27, 29,  3]), array([ 5, 27, 28, ..., 27, 29,  3]), array([ 5, 27, 28, ..., 27, 29,  3]), array([ 5, 27, 28, ..., 27, 29,  3]), array([ 5, 27, 28, ..., 27, 29,  3]), array([ 5, 27, 28, ..., 27, 29,  3]), array([ 5, 27, 28, ..., 27, 29,  3]), array([ 5, 27, 28, ..., 27, 29,  3])]
# [array([[2.03824490e-02, 1.67230645e-03, 3.28308460e-03, ...,
#         1.21595897e-02, 3.65753584e-02, 5.86824317e-04],
#        [2.82408932e-04, 2.22162740e-07, 1.86388046e-04, ...,
#         3.34154338e-01, 2.85636797e-03, 4.03860431e-05],
#        [4.24237065e-02, 4.01532234e-05, 1.30740404e-02, ...,
#         5.39906323e-03, 4.73838568e-01, 1.76659357e-02],
#        ...,
#        [4.37680595e-02, 6.92549685e-04, 5.40805794e-03, ...,
#         2.40870997e-01, 1.62807237e-02, 9.23176110e-03],
#        [1.64203748e-01, 8.49579349e-02, 8.42742505e-04, ...,
#         1.26757595e-05, 3.07490482e-05, 3.15266132e-01],
#        [4.61774645e-03, 4.00386658e-03, 2.95482352e-02, ...,
#         1.03110062e-04, 5.50522469e-04, 3.24757770e-04]], dtype=float32), array([[2.03824490e-02, 1.67230645e-03, 3.28308460e-03, ...,
#         1.21595897e-02, 3.65753584e-02, 5.86824317e-04],
#        [2.82408932e-04, 2.22162740e-07, 1.86388046e-04, ...,
#         3.34154338e-01, 2.85636797e-03, 4.03860431e-05],
#        [4.24237065e-02, 4.01532234e-05, 1.30740404e-02, ...,
#         5.39906323e-03, 4.73838568e-01, 1.76659357e-02],
#        ...,
#        [4.37680595e-02, 6.92549685e-04, 5.40805794e-03, ...,
#         2.40870997e-01, 1.62807237e-02, 9.23176110e-03],
#        [1.64203748e-01, 8.49579349e-02, 8.42742505e-04, ...,
#         1.26757595e-05, 3.07490482e-05, 3.15266132e-01],
#        [4.61774645e-03, 4.00386658e-03, 2.95482352e-02, ...,
#         1.03110062e-04, 5.50522469e-04, 3.24757770e-04]], dtype=float32), array([[2.03824490e-02, 1.67230645e-03, 3.28308460e-03, ...,
#         1.21595897e-02, 3.65753584e-02, 5.86824317e-04],
#        [2.82408932e-04, 2.22162740e-07, 1.86388046e-04, ...,
#         3.34154338e-01, 2.85636797e-03, 4.03860431e-05],
#        [4.24237065e-02, 4.01532234e-05, 1.30740404e-02, ...,
#         5.39906323e-03, 4.73838568e-01, 1.76659357e-02],
#        ...,
#        [4.37680595e-02, 6.92549685e-04, 5.40805794e-03, ...,
#         2.40870997e-01, 1.62807237e-02, 9.23176110e-03],
#        [1.64203748e-01, 8.49579349e-02, 8.42742505e-04, ...,
#         1.26757595e-05, 3.07490482e-05, 3.15266132e-01],
#        [4.61774645e-03, 4.00386658e-03, 2.95482352e-02, ...,
#         1.03110062e-04, 5.50522469e-04, 3.24757770e-04]], dtype=float32), array([[2.03824490e-02, 1.67230645e-03, 3.28308460e-03, ...,
#         1.21595897e-02, 3.65753584e-02, 5.86824317e-04],
#        [2.82408932e-04, 2.22162740e-07, 1.86388046e-04, ...,
#         3.34154338e-01, 2.85636797e-03, 4.03860431e-05],
#        [4.24237065e-02, 4.01532234e-05, 1.30740404e-02, ...,
#         5.39906323e-03, 4.73838568e-01, 1.76659357e-02],
#        ...,
#        [4.37680595e-02, 6.92549685e-04, 5.40805794e-03, ...,
#         2.40870997e-01, 1.62807237e-02, 9.23176110e-03],
#        [1.64203748e-01, 8.49579349e-02, 8.42742505e-04, ...,
#         1.26757595e-05, 3.07490482e-05, 3.15266132e-01],
#        [4.61774645e-03, 4.00386658e-03, 2.95482352e-02, ...,
#         1.03110062e-04, 5.50522469e-04, 3.24757770e-04]], dtype=float32), array([[2.03824490e-02, 1.67230645e-03, 3.28308460e-03, ...,
#         1.21595897e-02, 3.65753584e-02, 5.86824317e-04],
#        [2.82408932e-04, 2.22162740e-07, 1.86388046e-04, ...,
#         3.34154338e-01, 2.85636797e-03, 4.03860431e-05],
#        [4.24237065e-02, 4.01532234e-05, 1.30740404e-02, ...,
#         5.39906323e-03, 4.73838568e-01, 1.76659357e-02],
#        ...,
#        [4.37680595e-02, 6.92549685e-04, 5.40805794e-03, ...,
#         2.40870997e-01, 1.62807237e-02, 9.23176110e-03],
#        [1.64203748e-01, 8.49579349e-02, 8.42742505e-04, ...,
#         1.26757595e-05, 3.07490482e-05, 3.15266132e-01],
#        [4.61774645e-03, 4.00386658e-03, 2.95482352e-02, ...,
#         1.03110062e-04, 5.50522469e-04, 3.24757770e-04]], dtype=float32), array([[2.03824490e-02, 1.67230645e-03, 3.28308460e-03, ...,
#         1.21595897e-02, 3.65753584e-02, 5.86824317e-04],
#        [2.82408932e-04, 2.22162740e-07, 1.86388046e-04, ...,
#         3.34154338e-01, 2.85636797e-03, 4.03860431e-05],
#        [4.24237065e-02, 4.01532234e-05, 1.30740404e-02, ...,
#         5.39906323e-03, 4.73838568e-01, 1.76659357e-02],
#        ...,
#        [4.37680595e-02, 6.92549685e-04, 5.40805794e-03, ...,
#         2.40870997e-01, 1.62807237e-02, 9.23176110e-03],
#        [1.64203748e-01, 8.49579349e-02, 8.42742505e-04, ...,
#         1.26757595e-05, 3.07490482e-05, 3.15266132e-01],
#        [4.61774645e-03, 4.00386658e-03, 2.95482352e-02, ...,
#         1.03110062e-04, 5.50522469e-04, 3.24757770e-04]], dtype=float32), array([[2.03824490e-02, 1.67230645e-03, 3.28308460e-03, ...,
#         1.21595897e-02, 3.65753584e-02, 5.86824317e-04],
#        [2.82408932e-04, 2.22162740e-07, 1.86388046e-04, ...,
#         3.34154338e-01, 2.85636797e-03, 4.03860431e-05],
#        [4.24237065e-02, 4.01532234e-05, 1.30740404e-02, ...,
#         5.39906323e-03, 4.73838568e-01, 1.76659357e-02],
#        ...,
#        [4.37680595e-02, 6.92549685e-04, 5.40805794e-03, ...,
#         2.40870997e-01, 1.62807237e-02, 9.23176110e-03],
#        [1.64203748e-01, 8.49579349e-02, 8.42742505e-04, ...,
#         1.26757595e-05, 3.07490482e-05, 3.15266132e-01],
#        [4.61774645e-03, 4.00386658e-03, 2.95482352e-02, ...,
#         1.03110062e-04, 5.50522469e-04, 3.24757770e-04]], dtype=float32), array([[2.03824490e-02, 1.67230645e-03, 3.28308460e-03, ...,
#         1.21595897e-02, 3.65753584e-02, 5.86824317e-04],
#        [2.82408932e-04, 2.22162740e-07, 1.86388046e-04, ...,
#         3.34154338e-01, 2.85636797e-03, 4.03860431e-05],
#        [4.24237065e-02, 4.01532234e-05, 1.30740404e-02, ...,
#         5.39906323e-03, 4.73838568e-01, 1.76659357e-02],
#        ...,
#        [4.37680595e-02, 6.92549685e-04, 5.40805794e-03, ...,
#         2.40870997e-01, 1.62807237e-02, 9.23176110e-03],
#        [1.64203748e-01, 8.49579349e-02, 8.42742505e-04, ...,
#         1.26757595e-05, 3.07490482e-05, 3.15266132e-01],
#        [4.61774645e-03, 4.00386658e-03, 2.95482352e-02, ...,
#         1.03110062e-04, 5.50522469e-04, 3.24757770e-04]], dtype=float32), array([[2.03824490e-02, 1.67230645e-03, 3.28308460e-03, ...,
#         1.21595897e-02, 3.65753584e-02, 5.86824317e-04],
#        [2.82408932e-04, 2.22162740e-07, 1.86388046e-04, ...,
#         3.34154338e-01, 2.85636797e-03, 4.03860431e-05],
#        [4.24237065e-02, 4.01532234e-05, 1.30740404e-02, ...,
#         5.39906323e-03, 4.73838568e-01, 1.76659357e-02],
#        ...,
#        [4.37680595e-02, 6.92549685e-04, 5.40805794e-03, ...,
#         2.40870997e-01, 1.62807237e-02, 9.23176110e-03],
#        [1.64203748e-01, 8.49579349e-02, 8.42742505e-04, ...,
#         1.26757595e-05, 3.07490482e-05, 3.15266132e-01],
#        [4.61774645e-03, 4.00386658e-03, 2.95482352e-02, ...,
#         1.03110062e-04, 5.50522469e-04, 3.24757770e-04]], dtype=float32), array([[2.03824490e-02, 1.67230645e-03, 3.28308460e-03, ...,
#         1.21595897e-02, 3.65753584e-02, 5.86824317e-04],
#        [2.82408932e-04, 2.22162740e-07, 1.86388046e-04, ...,
#         3.34154338e-01, 2.85636797e-03, 4.03860431e-05],
#        [4.24237065e-02, 4.01532234e-05, 1.30740404e-02, ...,
#         5.39906323e-03, 4.73838568e-01, 1.76659357e-02],
#        ...,
#        [4.37680595e-02, 6.92549685e-04, 5.40805794e-03, ...,
#         2.40870997e-01, 1.62807237e-02, 9.23176110e-03],
#        [1.64203748e-01, 8.49579349e-02, 8.42742505e-04, ...,
#         1.26757595e-05, 3.07490482e-05, 3.15266132e-01],
#        [4.61774645e-03, 4.00386658e-03, 2.95482352e-02, ...,
#         1.03110062e-04, 5.50522469e-04, 3.24757770e-04]], dtype=float32), array([[2.03824490e-02, 1.67230645e-03, 3.28308460e-03, ...,
#         1.21595897e-02, 3.65753584e-02, 5.86824317e-04],
#        [2.82408932e-04, 2.22162740e-07, 1.86388046e-04, ...,
#         3.34154338e-01, 2.85636797e-03, 4.03860431e-05],
#        [4.24237065e-02, 4.01532234e-05, 1.30740404e-02, ...,
#         5.39906323e-03, 4.73838568e-01, 1.76659357e-02],
#        ...,
#        [4.37680595e-02, 6.92549685e-04, 5.40805794e-03, ...,
#         2.40870997e-01, 1.62807237e-02, 9.23176110e-03],
#        [1.64203748e-01, 8.49579349e-02, 8.42742505e-04, ...,
#         1.26757595e-05, 3.07490482e-05, 3.15266132e-01],
#        [4.61774645e-03, 4.00386658e-03, 2.95482352e-02, ...,
#         1.03110062e-04, 5.50522469e-04, 3.24757770e-04]], dtype=float32), array([[2.03824490e-02, 1.67230645e-03, 3.28308460e-03, ...,
#         1.21595897e-02, 3.65753584e-02, 5.86824317e-04],
#        [2.82408932e-04, 2.22162740e-07, 1.86388046e-04, ...,
#         3.34154338e-01, 2.85636797e-03, 4.03860431e-05],
#        [4.24237065e-02, 4.01532234e-05, 1.30740404e-02, ...,
#         5.39906323e-03, 4.73838568e-01, 1.76659357e-02],
#        ...,
#        [4.37680595e-02, 6.92549685e-04, 5.40805794e-03, ...,
#         2.40870997e-01, 1.62807237e-02, 9.23176110e-03],
#        [1.64203748e-01, 8.49579349e-02, 8.42742505e-04, ...,
#         1.26757595e-05, 3.07490482e-05, 3.15266132e-01],
#        [4.61774645e-03, 4.00386658e-03, 2.95482352e-02, ...,
#         1.03110062e-04, 5.50522469e-04, 3.24757770e-04]], dtype=float32), array([[2.03824490e-02, 1.67230645e-03, 3.28308460e-03, ...,
#         1.21595897e-02, 3.65753584e-02, 5.86824317e-04],
#        [2.82408932e-04, 2.22162740e-07, 1.86388046e-04, ...,
#         3.34154338e-01, 2.85636797e-03, 4.03860431e-05],
#        [4.24237065e-02, 4.01532234e-05, 1.30740404e-02, ...,
#         5.39906323e-03, 4.73838568e-01, 1.76659357e-02],
#        ...,
#        [4.37680595e-02, 6.92549685e-04, 5.40805794e-03, ...,
#         2.40870997e-01, 1.62807237e-02, 9.23176110e-03],
#        [1.64203748e-01, 8.49579349e-02, 8.42742505e-04, ...,
#         1.26757595e-05, 3.07490482e-05, 3.15266132e-01],
#        [4.61774645e-03, 4.00386658e-03, 2.95482352e-02, ...,
#         1.03110062e-04, 5.50522469e-04, 3.24757770e-04]], dtype=float32), array([[2.03824490e-02, 1.67230645e-03, 3.28308460e-03, ...,
#         1.21595897e-02, 3.65753584e-02, 5.86824317e-04],
#        [2.82408932e-04, 2.22162740e-07, 1.86388046e-04, ...,
#         3.34154338e-01, 2.85636797e-03, 4.03860431e-05],
#        [4.24237065e-02, 4.01532234e-05, 1.30740404e-02, ...,
#         5.39906323e-03, 4.73838568e-01, 1.76659357e-02],
#        ...,
#        [4.37680595e-02, 6.92549685e-04, 5.40805794e-03, ...,
#         2.40870997e-01, 1.62807237e-02, 9.23176110e-03],
#        [1.64203748e-01, 8.49579349e-02, 8.42742505e-04, ...,
#         1.26757595e-05, 3.07490482e-05, 3.15266132e-01],
#        [4.61774645e-03, 4.00386658e-03, 2.95482352e-02, ...,
#         1.03110062e-04, 5.50522469e-04, 3.24757770e-04]], dtype=float32), array([[2.03824490e-02, 1.67230645e-03, 3.28308460e-03, ...,
#         1.21595897e-02, 3.65753584e-02, 5.86824317e-04],
#        [2.82408932e-04, 2.22162740e-07, 1.86388046e-04, ...,
#         3.34154338e-01, 2.85636797e-03, 4.03860431e-05],
#        [4.24237065e-02, 4.01532234e-05, 1.30740404e-02, ...,
#         5.39906323e-03, 4.73838568e-01, 1.76659357e-02],
#        ...,
#        [4.37680595e-02, 6.92549685e-04, 5.40805794e-03, ...,
#         2.40870997e-01, 1.62807237e-02, 9.23176110e-03],
#        [1.64203748e-01, 8.49579349e-02, 8.42742505e-04, ...,
#         1.26757595e-05, 3.07490482e-05, 3.15266132e-01],
#        [4.61774645e-03, 4.00386658e-03, 2.95482352e-02, ...,
#         1.03110062e-04, 5.50522469e-04, 3.24757770e-04]], dtype=float32), array([[2.03824490e-02, 1.67230645e-03, 3.28308460e-03, ...,
#         1.21595897e-02, 3.65753584e-02, 5.86824317e-04],
#        [2.82408932e-04, 2.22162740e-07, 1.86388046e-04, ...,
#         3.34154338e-01, 2.85636797e-03, 4.03860431e-05],
#        [4.24237065e-02, 4.01532234e-05, 1.30740404e-02, ...,
#         5.39906323e-03, 4.73838568e-01, 1.76659357e-02],
#        ...,
#        [4.37680595e-02, 6.92549685e-04, 5.40805794e-03, ...,
#         2.40870997e-01, 1.62807237e-02, 9.23176110e-03],
#        [1.64203748e-01, 8.49579349e-02, 8.42742505e-04, ...,
#         1.26757595e-05, 3.07490482e-05, 3.15266132e-01],
#        [4.61774645e-03, 4.00386658e-03, 2.95482352e-02, ...,
#         1.03110062e-04, 5.50522469e-04, 3.24757770e-04]], dtype=float32), array([[2.03824490e-02, 1.67230645e-03, 3.28308460e-03, ...,
#         1.21595897e-02, 3.65753584e-02, 5.86824317e-04],
#        [2.82408932e-04, 2.22162740e-07, 1.86388046e-04, ...,
#         3.34154338e-01, 2.85636797e-03, 4.03860431e-05],
#        [4.24237065e-02, 4.01532234e-05, 1.30740404e-02, ...,
#         5.39906323e-03, 4.73838568e-01, 1.76659357e-02],
#        ...,
#        [4.37680595e-02, 6.92549685e-04, 5.40805794e-03, ...,
#         2.40870997e-01, 1.62807237e-02, 9.23176110e-03],
#        [1.64203748e-01, 8.49579349e-02, 8.42742505e-04, ...,
#         1.26757595e-05, 3.07490482e-05, 3.15266132e-01],
#        [4.61774645e-03, 4.00386658e-03, 2.95482352e-02, ...,
#         1.03110062e-04, 5.50522469e-04, 3.24757770e-04]], dtype=float32), array([[2.03824490e-02, 1.67230645e-03, 3.28308460e-03, ...,
#         1.21595897e-02, 3.65753584e-02, 5.86824317e-04],
#        [2.82408932e-04, 2.22162740e-07, 1.86388046e-04, ...,
#         3.34154338e-01, 2.85636797e-03, 4.03860431e-05],
#        [4.24237065e-02, 4.01532234e-05, 1.30740404e-02, ...,
#         5.39906323e-03, 4.73838568e-01, 1.76659357e-02],
#        ...,
#        [4.37680595e-02, 6.92549685e-04, 5.40805794e-03, ...,
#         2.40870997e-01, 1.62807237e-02, 9.23176110e-03],
#        [1.64203748e-01, 8.49579349e-02, 8.42742505e-04, ...,
#         1.26757595e-05, 3.07490482e-05, 3.15266132e-01],
#        [4.61774645e-03, 4.00386658e-03, 2.95482352e-02, ...,
#         1.03110062e-04, 5.50522469e-04, 3.24757770e-04]], dtype=float32), array([[2.03824490e-02, 1.67230645e-03, 3.28308460e-03, ...,
#         1.21595897e-02, 3.65753584e-02, 5.86824317e-04],
#        [2.82408932e-04, 2.22162740e-07, 1.86388046e-04, ...,
#         3.34154338e-01, 2.85636797e-03, 4.03860431e-05],
#        [4.24237065e-02, 4.01532234e-05, 1.30740404e-02, ...,
#         5.39906323e-03, 4.73838568e-01, 1.76659357e-02],
#        ...,
#        [4.37680595e-02, 6.92549685e-04, 5.40805794e-03, ...,
#         2.40870997e-01, 1.62807237e-02, 9.23176110e-03],
#        [1.64203748e-01, 8.49579349e-02, 8.42742505e-04, ...,
#         1.26757595e-05, 3.07490482e-05, 3.15266132e-01],
#        [4.61774645e-03, 4.00386658e-03, 2.95482352e-02, ...,
#         1.03110062e-04, 5.50522469e-04, 3.24757770e-04]], dtype=float32), array([[2.03824490e-02, 1.67230645e-03, 3.28308460e-03, ...,
#         1.21595897e-02, 3.65753584e-02, 5.86824317e-04],
#        [2.82408932e-04, 2.22162740e-07, 1.86388046e-04, ...,
#         3.34154338e-01, 2.85636797e-03, 4.03860431e-05],
#        [4.24237065e-02, 4.01532234e-05, 1.30740404e-02, ...,
#         5.39906323e-03, 4.73838568e-01, 1.76659357e-02],
#        ...,
#        [4.37680595e-02, 6.92549685e-04, 5.40805794e-03, ...,
#         2.40870997e-01, 1.62807237e-02, 9.23176110e-03],
#        [1.64203748e-01, 8.49579349e-02, 8.42742505e-04, ...,
#         1.26757595e-05, 3.07490482e-05, 3.15266132e-01],
#        [4.61774645e-03, 4.00386658e-03, 2.95482352e-02, ...,
#         1.03110062e-04, 5.50522469e-04, 3.24757770e-04]], dtype=float32)]
# [array([[2.03824490e-02, 1.67230645e-03, 3.28308460e-03, ...,
#         1.21595897e-02, 3.65753584e-02, 5.86824317e-04],
#        [2.82408932e-04, 2.22162740e-07, 1.86388046e-04, ...,
#         3.34154338e-01, 2.85636797e-03, 4.03860431e-05],
#        [4.24237065e-02, 4.01532234e-05, 1.30740404e-02, ...,
#         5.39906323e-03, 4.73838568e-01, 1.76659357e-02],
#        ...,
#        [4.37680595e-02, 6.92549685e-04, 5.40805794e-03, ...,
#         2.40870997e-01, 1.62807237e-02, 9.23176110e-03],
#        [1.64203748e-01, 8.49579349e-02, 8.42742505e-04, ...,
#         1.26757595e-05, 3.07490482e-05, 3.15266132e-01],
#        [4.61774645e-03, 4.00386658e-03, 2.95482352e-02, ...,
#         1.03110062e-04, 5.50522469e-04, 3.24757770e-04]], dtype=float32), array([[2.03037057e-02, 2.05643126e-03, 3.55703081e-03, ...,
#         1.35733075e-02, 3.22181396e-02, 9.62973689e-04],
#        [1.36693576e-04, 2.36032506e-07, 5.49786855e-05, ...,
#         6.95712119e-02, 7.30281405e-04, 1.52710054e-04],
#        [5.26900440e-02, 3.31327283e-05, 4.57379082e-03, ...,
#         6.60537183e-03, 4.37291205e-01, 7.98423495e-03],
#        ...,
#        [6.10027499e-02, 8.02342605e-04, 3.53763299e-03, ...,
#         1.43236846e-01, 2.77701356e-02, 1.73082538e-02],
#        [1.12469025e-01, 5.06074876e-02, 9.98914707e-04, ...,
#         1.86633570e-05, 7.83215291e-05, 3.43524545e-01],
#        [2.34974572e-03, 9.30309389e-03, 1.10138617e-02, ...,
#         4.90055136e-05, 3.84374725e-05, 2.83688831e-04]], dtype=float32), array([[2.07960550e-02, 3.87482764e-03, 9.66366939e-03, ...,
#         4.31939447e-03, 3.92960496e-02, 3.12671554e-03],
#        [6.76227719e-05, 2.02508389e-07, 9.46755608e-06, ...,
#         2.02689064e-03, 1.98380192e-04, 9.61194979e-04],
#        [1.78857315e-02, 1.99638889e-04, 7.86186382e-03, ...,
#         1.38392719e-02, 8.55614692e-02, 9.05958377e-03],
#        ...,
#        [2.12932155e-02, 4.55787405e-04, 6.69363420e-04, ...,
#         3.09448931e-02, 4.88944277e-02, 1.56303756e-02],
#        [5.4186781e-05, 1.6456102e-08, 4.8315446e-08, ..., 2.9495408e-04,
#         3.3302107e-04, 1.6533681e-05],
#        [2.0452492e-06, 2.1385389e-10, 6.5675709e-09, ..., 1.9814965e-05,
#         4.3514858e-05, 5.8407704e-06],
#        ...,
#        [2.2236821e-04, 2.0197753e-08, 1.1862096e-09, ..., 7.6649858e-06,
#         5.0658459e-04, 1.7254461e-05],
#        [1.8311783e-05, 5.2364840e-07, 1.4792059e-07, ..., 9.2455036e-07,
#         2.4997717e-04, 8.7990117e-04],
#        [2.4538292e-04, 3.3652984e-08, 4.5027666e-09, ..., 2.9722657e-06,
#         1.2783556e-04, 2.1387929e-04]], dtype=float32), array([[3.42035200e-05, 2.82960940e-07, 3.61699151e-08, ...,
#         9.71215172e-07, 5.48747594e-05, 2.07527773e-04],
#        [5.53229984e-05, 6.00341355e-06, 4.45043042e-07, ...,
#         4.92757044e-06, 9.04202607e-05, 3.21721495e-03],
#        [3.63702893e-05, 1.59434421e-06, 2.42372181e-07, ...,
#         8.00339762e-07, 1.66664086e-06, 2.57631857e-03],
#        ...,
#        [6.03675609e-04, 8.62644299e-07, 1.19888693e-06, ...,
#         1.91001363e-05, 9.13915748e-04, 4.97506640e-04],
#        [1.15692406e-03, 8.30631564e-07, 1.91680624e-06, ...,
#         1.65619713e-04, 1.15983654e-04, 2.09388905e-03],
#        [6.34502769e-02, 2.91979144e-04, 7.33686466e-06, ...,
#         2.30130419e-04, 1.20826566e-03, 1.34844764e-03]], dtype=float32), array([[1.7579325e-05, 1.8363070e-07, 2.9242569e-08, ..., 5.0817857e-07,
#         5.7583798e-05, 5.0384778e-04],
#        [1.1010673e-03, 8.1310736e-06, 4.2463628e-07, ..., 3.6598991e-05,
#         1.2446642e-03, 3.8652648e-03],
#        [7.1605588e-03, 2.6145265e-06, 1.3384542e-07, ..., 7.7892457e-07,
#         3.7369167e-03, 1.0494018e-03],
#        ...,
#        [3.9636820e-05, 5.5766126e-08, 2.3442963e-08, ..., 8.6054652e-06,
#         3.7642592e-05, 6.8261550e-04],
#        [3.0862281e-04, 1.8269660e-06, 4.3014302e-06, ..., 1.8866059e-04,
#         4.3057723e-04, 7.1063917e-04],
#        [2.2761745e-04, 5.4313796e-07, 3.7182053e-07, ..., 7.0176233e-05,
#         5.8909305e-03, 2.0436865e-04]], dtype=float32)]
# [array([ 5, 27, 28, ..., 27, 29,  3]), array([ 5,  7, 28, ..., 27, 29,  3]), array([26,  7, 26, ..., 12, 29, 15]), array([ 5,  7, 26, ...,  8, 29, 15]), array([ 5,  7, 26, ..., 12, 29, 15]), array([12,  7,  8, ..., 24,  8, 15]), array([ 8,  7, 12, ...,  7,  8, 15]), array([ 8, 24, 26, ..., 21, 12, 24]), array([ 8,  8, 26, ..., 21, 21, 16]), array([12, 24,  8, ..., 12,  8, 24]), array([21, 24,  8, ..., 21,  8, 17]), array([21,  7, 12, ...,  8,  8, 12]), array([12, 24, 12, ..., 21, 12, 24]), array([12, 24, 12, ..., 12, 21, 24]), array([21, 24, 12, ..., 21, 21,  8]), array([21, 24, 12, ..., 24, 21, 24]), array([12,  7, 26, ..., 12, 12, 24]), array([21, 12, 24, ..., 12,  8, 12]), array([21,  8,  8, ..., 24, 24, 24]), array([21, 21, 21, ...,  8, 24, 24])]

# %%
import csv

# %%
with open('y_reference_list.csv','w',newline='') as file:
  writer=csv.writer(file)
  writer.writerow(y_reference_list)

# %%
import os
import cv2
import numpy as np
from keras.preprocessing.image import img_to_array
from sklearn.preprocessing import LabelBinarizer
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
from keras.callbacks import LearningRateScheduler
from sklearn.metrics import f1_score, accuracy_score, precision_score, recall_score, classification_report
import time
import tensorflow as tf

# Define distillation loss function if needed (dummy placeholder here)
def distillation_loss(y_true, y_pred):
    return tf.keras.losses.categorical_crossentropy(y_true, y_pred)

# Load models from .h5 files without compiling, then compile manually
teacher = tf.keras.models.load_model('teacher_model.h5', compile=False)
teacher.compile(optimizer=tf.keras.optimizers.SGD(), loss='categorical_crossentropy', metrics=['accuracy'])

student = tf.keras.models.load_model('student_model.h5', compile=False)
student.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=1e-3),
                loss='categorical_crossentropy', metrics=['accuracy'])

# Assuming you already have preprocessed data ready in x_test and y_test
# If not, load your data here:
data_path = 'aid-scene-classification-datasets/AID'  # adjust path as needed
image_data = []
labels = []

for root, dirs, files in os.walk(data_path):
    for file in files:
        if file.endswith(".jpg"):
            image = cv2.imread(os.path.join(root, file))
            image = cv2.resize(image, (32, 32))
            image = img_to_array(image)
            image_data.append(image)
            label = root.split(os.path.sep)[-1]
            labels.append(label)

image_data = np.array(image_data, dtype="float") / 255.0
labels = np.array(labels)

lb = LabelBinarizer()
labels = lb.fit_transform(labels)

x_train, x_test, y_train, y_test = train_test_split(image_data, labels, test_size=0.2, random_state=42)

# Evaluate Teacher Model
teacher_score = teacher.evaluate(x_test, y_test, verbose=0)
print(f'Teacher test accuracy: {teacher_score[1] * 100:.2f}%')

# Teacher predictions (for distillation)
teacher_preds = teacher.predict(x_train)

# Student Evaluation on Clean Test Set
start_time = time.time()
y_pred_probs = student.predict(x_test)
inference_time = time.time() - start_time

y_pred = np.argmax(y_pred_probs, axis=1)
y_true = np.argmax(y_test, axis=1)

print("\n=== Final Student Model Evaluation on Clean Test Set ===")
print(classification_report(y_true, y_pred, target_names=lb.classes_))
print(f"Inference Time: {inference_time:.4f} seconds")

# Robustness Evaluation Against Gaussian Noise
y_reference_probs = student.predict(x_test)
y_reference = np.argmax(y_reference_probs, axis=1)

stddev_values = np.linspace(0, 1, 20)

for stddev in stddev_values:
    noise = np.random.normal(loc=0.0, scale=stddev, size=x_test.shape)
    x_noisy = np.clip(x_test + noise, 0., 1.)

    y_pred_noisy_probs = student.predict(x_noisy)
    y_pred_noisy = np.argmax(y_pred_noisy_probs, axis=1)

    acc = accuracy_score(y_reference, y_pred_noisy)
    f1 = f1_score(y_reference, y_pred_noisy, average='weighted')
    precision = precision_score(y_reference, y_pred_noisy, average='weighted')
    recall = recall_score(y_reference, y_pred_noisy, average='weighted')

    print(f"Noise STDDEV = {stddev:.2f} -> Accuracy = {acc:.4f}, F1 = {f1:.4f}, Precision = {precision:.4f}, Recall = {recall:.4f}")
# Out:
# Teacher test accuracy: 62.75%
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 23s 93ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step
#
# === Final Student Model Evaluation on Clean Test Set ===
#                    precision    recall  f1-score   support
#
#           Airport       0.57      0.58      0.58        77
#          BareLand       0.79      0.81      0.80        59
#     BaseballField       0.88      0.86      0.87        42
#             Beach       0.87      0.89      0.88        80
#            Bridge       0.89      0.79      0.84        63
#            Center       0.66      0.61      0.63        54
#            Church       0.65      0.58      0.61        52
#        Commercial       0.51      0.49      0.50        88
#  DenseResidential       0.57      0.84      0.68        86
#            Desert       0.82      0.86      0.84        59
#          Farmland       0.71      0.67      0.69        78
#            Forest       0.88      0.93      0.90        40
#        Industrial       0.42      0.46      0.44        85
#            Meadow       0.90      0.85      0.87        52
# MediumResidential       0.64      0.57      0.60        56
#          Mountain       0.56      0.51      0.53        68
#              Park       0.65      0.56      0.60        81
#           Parking       0.87      0.76      0.81        80
#        Playground       0.79      0.90      0.84        58
#              Pond       0.85      0.80      0.83        80
#              Port       0.84      0.77      0.81        84
#    RailwayStation       0.52      0.50      0.51        54
#            Resort       0.49      0.41      0.45        61
#             River       0.57      0.53      0.55        73
#            School       0.29      0.28      0.28        58
# SparseResidential       0.90      0.79      0.84        66
#            Square       0.42      0.41      0.41        66
#           Stadium       0.84      0.93      0.88        55
#      StorageTanks       0.54      0.54      0.54        71
#           Viaduct       0.35      0.49      0.40        74
#
#          accuracy                           0.66      2000
#         macro avg       0.67      0.67      0.67      2000
#      weighted avg       0.67      0.66      0.66      2000
#
# Inference Time: 1.8487 seconds
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 3s 40ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step
# Noise STDDEV = 0.00 -> Accuracy = 1.0000, F1 = 1.0000, Precision = 1.0000, Recall = 1.0000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 2s 40ms/step
# Noise STDDEV = 0.05 -> Accuracy = 0.7965, F1 = 0.7965, Precision = 0.8199, Recall = 0.7965
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 2s 27ms/step
# Noise STDDEV = 0.11 -> Accuracy = 0.5285, F1 = 0.5052, Precision = 0.6435, Recall = 0.5285
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step
# Noise STDDEV = 0.16 -> Accuracy = 0.3485, F1 = 0.3122, Precision = 0.5118, Recall = 0.3485
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# Noise STDDEV = 0.21 -> Accuracy = 0.2420, F1 = 0.1945, Precision = 0.3430, Recall = 0.2420
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step
# Noise STDDEV = 0.26 -> Accuracy = 0.1825, F1 = 0.1367, Precision = 0.2951, Recall = 0.1825
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step
# Noise STDDEV = 0.32 -> Accuracy = 0.1525, F1 = 0.1098, Precision = 0.2340, Recall = 0.1525
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# Noise STDDEV = 0.37 -> Accuracy = 0.1080, F1 = 0.0712, Precision = 0.1716, Recall = 0.1080
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 2s 32ms/step
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# Noise STDDEV = 0.42 -> Accuracy = 0.0975, F1 = 0.0602, Precision = 0.1148, Recall = 0.0975
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step
# Noise STDDEV = 0.47 -> Accuracy = 0.0870, F1 = 0.0530, Precision = 0.1357, Recall = 0.0870
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# Noise STDDEV = 0.53 -> Accuracy = 0.0700, F1 = 0.0384, Precision = 0.1104, Recall = 0.0700
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# Noise STDDEV = 0.58 -> Accuracy = 0.0695, F1 = 0.0359, Precision = 0.1219, Recall = 0.0695
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 2s 33ms/step
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# Noise STDDEV = 0.63 -> Accuracy = 0.0640, F1 = 0.0303, Precision = 0.0575, Recall = 0.0640
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# Noise STDDEV = 0.68 -> Accuracy = 0.0560, F1 = 0.0251, Precision = 0.0530, Recall = 0.0560
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# Noise STDDEV = 0.74 -> Accuracy = 0.0515, F1 = 0.0184, Precision = 0.0306, Recall = 0.0515
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step
# Noise STDDEV = 0.79 -> Accuracy = 0.0540, F1 = 0.0163, Precision = 0.0105, Recall = 0.0540
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# Noise STDDEV = 0.84 -> Accuracy = 0.0490, F1 = 0.0193, Precision = 0.0477, Recall = 0.0490
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 3s 39ms/step
# Noise STDDEV = 0.89 -> Accuracy = 0.0565, F1 = 0.0223, Precision = 0.0566, Recall = 0.0565
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step
# Noise STDDEV = 0.95 -> Accuracy = 0.0490, F1 = 0.0198, Precision = 0.0628, Recall = 0.0490
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step
# Noise STDDEV =
#         2.30130419e-04, 1.20826566e-03, 1.34844764e-03]], dtype=float32), array([[1.7579325e-05, 1.8363070e-07, 2.9242569e-08, ..., 5.0817857e-07,
#         5.7583798e-05, 5.0384778e-04],
#        [1.1010673e-03, 8.1310736e-06, 4.2463628e-07, ..., 3.6598991e-05,
#         1.2446642e-03, 3.8652648e-03],
#        [7.1605588e-03, 2.6145265e-06, 1.3384542e-07, ..., 7.7892457e-07,
#         3.7369167e-03, 1.0494018e-03],
#        ...,
#        [3.9636820e-05, 5.5766126e-08, 2.3442963e-08, ..., 8.6054652e-06,
#         3.7642592e-05, 6.8261550e-04],
#        [3.0862281e-04, 1.8269660e-06, 4.3014302e-06, ..., 1.8866059e-04,
#         4.3057723e-04, 7.1063917e-04],
#        [2.2761745e-04, 5.4313796e-07, 3.7182053e-07, ..., 7.0176233e-05,
#         5.8909305e-03, 2.0436865e-04]], dtype=float32)]
# [array([ 5, 27, 28, ..., 27, 29,  3]), array([ 5,  7, 28, ..., 27, 29,  3]), array([26,  7, 26, ..., 12, 29, 15]), array([ 5,  7, 26, ...,  8, 29, 15]), array([ 5,  7, 26, ..., 12, 29, 15]), array([12,  7,  8, ..., 24,  8, 15]), array([ 8,  7, 12, ...,  7,  8, 15]), array([ 8, 24, 26, ..., 21, 12, 24]), array([ 8,  8, 26, ..., 21, 21, 16]), array([12, 24,  8, ..., 12,  8, 24]), array([21, 24,  8, ..., 21,  8, 17]), array([21,  7, 12, ...,  8,  8, 12]), array([12, 24, 12, ..., 21, 12, 24]), array([12, 24, 12, ..., 12, 21, 24]), array([21, 24, 12, ..., 21, 21,  8]), array([21, 24, 12, ..., 24, 21, 24]), array([12,  7, 26, ..., 12, 12, 24]), array([21, 12, 24, ..., 12,  8, 12]), array([21,  8,  8, ..., 24, 24, 24]), array([21, 21, 21, ...,  8, 24, 24])]

# %%
import os
import cv2
import numpy as np
from keras.preprocessing.image import img_to_array
from sklearn.preprocessing import LabelBinarizer
from sklearn.model_selection import train_test_split
from sklearn.metrics import f1_score, accuracy_score, precision_score, recall_score, classification_report
import time
import tensorflow as tf
from keras.callbacks import LearningRateScheduler

# Load models from .h5 files without compiling
teacher_1 = tf.keras.models.load_model('teacher_model_1.h5', compile=False)
student_1 = tf.keras.models.load_model('student_model_1.h5', compile=False)

# Load and preprocess data
data_path = 'aid-scene-classification-datasets/AID'
image_data = []
labels = []

for root, dirs, files in os.walk(data_path):
    for file in files:
        if file.endswith(".jpg"):
            image = cv2.imread(os.path.join(root, file))
            image = cv2.resize(image, (32, 32))
            image = img_to_array(image)
            image_data.append(image)
            label = root.split(os.path.sep)[-1]
            labels.append(label)

image_data = np.array(image_data, dtype="float") / 255.0
labels = np.array(labels)

lb = LabelBinarizer()
labels = lb.fit_transform(labels)

x_train, x_test, y_train, y_test = train_test_split(image_data, labels, test_size=0.2, random_state=42)

# Get teacher predictions for distillation
teacher_preds_1 = teacher_1.predict(x_train)

# Define distillation loss function with nuclear norm
def distillation_loss(y_true, y_pred, teacher_preds, temperature=3.0, alpha=0.25):
    teacher_batch_preds = tf.gather(teacher_preds, tf.range(tf.shape(y_pred)[0]))
    y_true_soft = tf.keras.activations.softmax(y_true / temperature)
    y_pred_soft = tf.keras.activations.softmax(y_pred / temperature)
    teacher_soft = tf.keras.activations.softmax(teacher_batch_preds / temperature)
    soft_loss = tf.keras.losses.categorical_crossentropy(teacher_soft, y_pred_soft)
    hard_loss = tf.keras.losses.categorical_crossentropy(y_true_soft, y_pred_soft)

    first_layer_weights = None
    for layer in student_1.layers:
        if layer.weights:
            first_layer_weights = layer.weights[0]
            break

    if first_layer_weights is not None:
        singular_values = tf.linalg.svd(first_layer_weights, compute_uv=False)
        nuclear_norm = tf.reduce_sum(singular_values)
    else:
        nuclear_norm = 0.

    return alpha * (soft_loss + 0.001 * nuclear_norm) + (1. - alpha) * hard_loss

def lr_scheduler(epoch, lr):
    return float(lr * tf.math.exp(-0.1)) if epoch >= 10 else float(lr)

# Compile student model with custom loss
student_1.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=1e-3),
    loss=lambda y_true, y_pred: distillation_loss(y_true, y_pred, teacher_preds_1),
    metrics=['accuracy']
)

# Retrain student model (if needed)
student_1.fit(x_train, y_train, batch_size=32, epochs=30, validation_data=(x_test, y_test), callbacks=[LearningRateScheduler(lr_scheduler)])

# Evaluate student on clean test set
start_time = time.time()
y_pred_probs = student_1.predict(x_test)
inference_time = time.time() - start_time

y_pred = np.argmax(y_pred_probs, axis=1)
y_true = np.argmax(y_test, axis=1)

print("\n=== Final Student Model Evaluation on Clean Test Set ===")
print(classification_report(y_true, y_pred, target_names=lb.classes_))
print(f"Inference Time: {inference_time:.4f} seconds")

# Robustness evaluation
y_reference_probs_1 = student_1.predict(x_test)
y_reference_1 = np.argmax(y_reference_probs_1, axis=1)

# stddev_values = np.linspace(0, 1, 20)

# for stddev in stddev_values:
#     noise = np.random.normal(loc=0.0, scale=stddev, size=x_test.shape)
#     x_noisy = np.clip(x_test + noise, 0., 1.)

#     y_pred_noisy_probs_1 = student_1.predict(x_noisy)
#     y_pred_noisy_1 = np.argmax(y_pred_noisy_probs_1, axis=1)

#     acc = accuracy_score(y_reference_1, y_pred_noisy_1)
#     f1 = f1_score(y_reference_1, y_pred_noisy_1, average='weighted')
#     precision = precision_score(y_reference_1, y_pred_noisy_1, average='weighted')
#     recall = recall_score(y_reference_1, y_pred_noisy_1, average='weighted')

#     print(f"Noise STDDEV = {stddev:.2f} -> Accuracy = {acc:.4f}, F1 = {f1:.4f}, Precision = {precision:.4f}, Recall = {recall:.4f}")

stddev_values = np.linspace(0, 1, 20)
noisy_accuracies, noisy_f1_scores, noisy_precisions, noisy_recalls = [], [], [], []
y_reference_list_1 = []
y_reference_probs_list_1 = []
y_pred_noisy_probs_list_1 = []
y_pred_noisy_list_1 = []

for stddev in stddev_values:
    noise = np.random.normal(loc=0.0, scale=stddev, size=x_test.shape)
    x_noisy = np.clip(x_test + noise, 0., 1.)

    y_pred_noisy_probs_1 = student_1.predict(x_noisy) ########
    y_pred_noisy_1 = np.argmax(y_pred_noisy_probs_1, axis=1)

    acc = accuracy_score(y_reference_1, y_pred_noisy_1)
    f1 = f1_score(y_reference_1, y_pred_noisy_1, average='weighted')
    precision = precision_score(y_reference_1, y_pred_noisy_1, average='weighted')
    recall = recall_score(y_reference_1, y_pred_noisy_1, average='weighted')

    noisy_accuracies.append(acc)
    noisy_f1_scores.append(f1)
    noisy_precisions.append(precision)
    noisy_recalls.append(recall)

    y_reference_list_1.append(y_reference_1)
    y_reference_probs_list_1.append(y_reference_probs_1)
    y_pred_noisy_probs_list_1.append(y_pred_noisy_probs_1)
    y_pred_noisy_list_1.append(y_pred_noisy_1)

    print(f"Noise STDDEV = {stddev:.2f} -> Accuracy = {acc:.4f}, F1 = {f1:.4f}, Precision = {precision:.4f}, Recall = {recall:.4f
# Epoch 24/30
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 25s 99ms/step - accuracy: 0.8685 - loss: 3.4004 - val_accuracy: 0.5945 - val_loss: 3.4008 - learning_rate: 2.4660e-04
# Epoch 25/30
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 41s 100ms/step - accuracy: 0.8864 - loss: 3.4003 - val_accuracy: 0.6105 - val_loss: 3.4008 - learning_rate: 2.2313e-04
# Epoch 26/30
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 26s 104ms/step - accuracy: 0.8875 - loss: 3.4003 - val_accuracy: 0.6090 - val_loss: 3.4008 - learning_rate: 2.0190e-04
# Epoch 27/30
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 40s 101ms/step - accuracy: 0.8988 - loss: 3.4003 - val_accuracy: 0.6130 - val_loss: 3.4007 - learning_rate: 1.8268e-04
# Epoch 28/30
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 25s 101ms/step - accuracy: 0.8958 - loss: 3.4003 - val_accuracy: 0.6175 - val_loss: 3.4007 - learning_rate: 1.6530e-04
# Epoch 29/30
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 24s 95ms/step - accuracy: 0.8921 - loss: 3.4003 - val_accuracy: 0.6155 - val_loss: 3.4007 - learning_rate: 1.4957e-04
# Epoch 30/30
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 42s 100ms/step - accuracy: 0.8973 - loss: 3.4003 - val_accuracy: 0.5830 - val_loss: 3.4008 - learning_rate: 1.3534e-04
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step
#
# === Final Student Model Evaluation on Clean Test Set ===
#                    precision    recall  f1-score   support
#
#           Airport       0.51      0.31      0.39        77
#          BareLand       0.65      0.86      0.74        59
#     BaseballField       0.91      0.71      0.80        42
#             Beach       0.93      0.84      0.88        80
#            Bridge       0.78      0.73      0.75        63
#            Center       0.64      0.63      0.64        54
#            Church       0.46      0.52      0.49        52
#        Commercial       0.50      0.62      0.55        88
#  DenseResidential       0.59      0.80      0.68        86
#            Desert       1.00      0.63      0.77        59
#          Farmland       0.62      0.37      0.46        78
#            Forest       0.60      0.93      0.73        40
#        Industrial       0.36      0.52      0.43        85
#            Meadow       0.80      0.77      0.78        52
# MediumResidential       0.59      0.34      0.43        56
#          Mountain       0.54      0.29      0.38        68
#              Park       0.43      0.46      0.44        81
#           Parking       0.76      0.80      0.78        80
#        Playground       0.70      0.81      0.75        58
#              Pond       0.87      0.68      0.76        80
#              Port       0.83      0.75      0.79        84
#    RailwayStation       0.28      0.44      0.34        54
#            Resort       0.56      0.31      0.40        61
#             River       0.52      0.45      0.48        73
#            School       0.28      0.28      0.28        58
# SparseResidential       0.81      0.86      0.84        66
#            Square       0.25      0.27      0.26        66
#           Stadium       0.85      0.93      0.89        55
#      StorageTanks       0.49      0.39      0.44        71
#           Viaduct       0.25      0.35      0.29        74
#
#          accuracy                           0.58      2000
#         macro avg       0.61      0.59      0.59      2000
#      weighted avg       0.61      0.58      0.58      2000
#
# Inference Time: 2.7858 seconds
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 2s 35ms/step
# Noise STDDEV = 0.00 -> Accuracy = 0.6595, F1 = 0.6586, Precision = 0.6775, Recall = 0.6595
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step
# Noise STDDEV = 0.05 -> Accuracy = 0.6160, F1 = 0.6197, Precision = 0.6477, Recall = 0.6160
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# Noise STDDEV = 0.11 -> Accuracy = 0.4785, F1 = 0.4626, Precision = 0.5561, Recall = 0.4785
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step
# Noise STDDEV = 0.16 -> Accuracy = 0.3385, F1 = 0.3144, Precision = 0.4564, Recall = 0.3385
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# Noise STDDEV = 0.21 -> Accuracy = 0.2480, F1 = 0.2097, Precision = 0.3800, Recall = 0.2480
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 2s 27ms/step
# Noise STDDEV = 0.26 -> Accuracy = 0.1955, F1 = 0.1529, Precision = 0.2691, Recall = 0.1955
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# Noise STDDEV = 0.32 -> Accuracy = 0.1610, F1 = 0.1254, Precision = 0.2578, Recall = 0.1610
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step
# Noise STDDEV = 0.37 -> Accuracy = 0.1360, F1 = 0.0973, Precision = 0.1865, Recall = 0.1360
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# Noise STDDEV = 0.42 -> Accuracy = 0.1180, F1 = 0.0850, Precision = 0.1442, Recall = 0.1180
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 2s 34ms/step
# Noise STDDEV = 0.47 -> Accuracy = 0.0890, F1 = 0.0540, Precision = 0.1568, Recall = 0.0890
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 2s 32ms/step
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# Noise STDDEV = 0.53 -> Accuracy = 0.0860, F1 = 0.0472, Precision = 0.1266, Recall = 0.0860
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# Noise STDDEV = 0.58 -> Accuracy = 0.0840, F1 = 0.0439, Precision = 0.1384, Recall = 0.0840
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step
# Noise STDDEV = 0.63 -> Accuracy = 0.0750, F1 = 0.0349, Precision = 0.1269, Recall = 0.0750
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step
# Noise STDDEV = 0.68 -> Accuracy = 0.0785, F1 = 0.0379, Precision = 0.0788, Recall = 0.0785
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step
# Noise STDDEV = 0.74 -> Accuracy = 0.0645, F1 = 0.0274, Precision = 0.0832, Recall = 0.0645
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 3s 39ms/step
# Noise STDDEV = 0.79 -> Accuracy = 0.0640, F1 = 0.0278, Precision = 0.0740, Recall = 0.0640
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step
# Noise STDDEV = 0.84 -> Accuracy = 0.0630, F1 = 0.0274, Precision = 0.0917, Recall = 0.0630
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step
# Noise STDDEV = 0.89 -> Accuracy = 0.0665, F1 = 0.0292, Precision = 0.0578, Recall = 0.0665
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step
# Noise STDDEV = 0.95 -> Accuracy = 0.0575, F1 = 0.0222, Precision = 0.0373, Recall = 0.0575
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step
# Noise STDDEV = 1.00 -> Accuracy = 0.0585, F1 = 0.0231, Precision = 0.0322, Recall = 0.0585
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))

# %%
y_reference_probs_1 = student_1.predict(x_test)
y_reference_1 = np.argmax(y_reference_probs_1, axis=1)

stddev_values = np.linspace(0, 1, 20)
noisy_accuracies, noisy_f1_scores, noisy_precisions, noisy_recalls = [], [], [], []
y_reference_list_1 = []
y_reference_probs_list_1 = []
y_pred_noisy_probs_list_1 = []
y_pred_noisy_list_1 = []

for stddev in stddev_values:
    noise = np.random.normal(loc=0.0, scale=stddev, size=x_test.shape)
    x_noisy = np.clip(x_test + noise, 0., 1.)

    y_pred_noisy_probs_1 = student_1.predict(x_noisy)
    y_pred_noisy_1 = np.argmax(y_pred_noisy_probs_1, axis=1)

    acc = accuracy_score(y_reference_1, y_pred_noisy_1)
    f1 = f1_score(y_reference_1, y_pred_noisy_1, average='weighted')
    precision = precision_score(y_reference_1, y_pred_noisy_1, average='weighted')
    recall = recall_score(y_reference_1, y_pred_noisy_1, average='weighted')

    noisy_accuracies.append(acc)
    noisy_f1_scores.append(f1)
    noisy_precisions.append(precision)
    noisy_recalls.append(recall)

    y_reference_list_1.append(y_reference_1)
    y_reference_probs_list_1.append(y_reference_probs_1)
    y_pred_noisy_probs_list_1.append(y_pred_noisy_probs_1)
    y_pred_noisy_list_1.append(y_pred_noisy_1)

    print(f"Noise STDDEV = {stddev:.2f} -> Accuracy = {acc:.4f}, F1 = {f1:.4f}, Precision = {precision:.4f}, Recall = {recall:.4f}")
# Out:
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 2s 35ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 2s 31ms/step
# Noise STDDEV = 0.00 -> Accuracy = 1.0000, F1 = 1.0000, Precision = 1.0000, Recall = 1.0000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step
# Noise STDDEV = 0.05 -> Accuracy = 0.7965, F1 = 0.7911, Precision = 0.8286, Recall = 0.7965
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step
# Noise STDDEV = 0.11 -> Accuracy = 0.5575, F1 = 0.5298, Precision = 0.6727, Recall = 0.5575
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step
# Noise STDDEV = 0.16 -> Accuracy = 0.3900, F1 = 0.3485, Precision = 0.5110, Recall = 0.3900
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step
# Noise STDDEV = 0.21 -> Accuracy = 0.2935, F1 = 0.2506, Precision = 0.4264, Recall = 0.2935
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 2s 39ms/step
# Noise STDDEV = 0.26 -> Accuracy = 0.2170, F1 = 0.1787, Precision = 0.3733, Recall = 0.2170
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# Noise STDDEV = 0.32 -> Accuracy = 0.1725, F1 = 0.1341, Precision = 0.2051, Recall = 0.1725
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step
# Noise STDDEV = 0.37 -> Accuracy = 0.1340, F1 = 0.0951, Precision = 0.1882, Recall = 0.1340
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# Noise STDDEV = 0.42 -> Accuracy = 0.1180, F1 = 0.0763, Precision = 0.1710, Recall = 0.1180
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step
# Noise STDDEV = 0.47 -> Accuracy = 0.1095, F1 = 0.0642, Precision = 0.1812, Recall = 0.1095
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 2s 37ms/step
# Noise STDDEV = 0.53 -> Accuracy = 0.1000, F1 = 0.0535, Precision = 0.1488, Recall = 0.1000
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 2s 27ms/step
# Noise STDDEV = 0.58 -> Accuracy = 0.0960, F1 = 0.0502, Precision = 0.1714, Recall = 0.0960
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step
# Noise STDDEV = 0.63 -> Accuracy = 0.0825, F1 = 0.0333, Precision = 0.0614, Recall = 0.0825
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step
# Noise STDDEV = 0.68 -> Accuracy = 0.0845, F1 = 0.0361, Precision = 0.0974, Recall = 0.0845
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# Noise STDDEV = 0.74 -> Accuracy = 0.0735, F1 = 0.0320, Precision = 0.1186, Recall = 0.0735
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step
# Noise STDDEV = 0.79 -> Accuracy = 0.0620, F1 = 0.0189, Precision = 0.0178, Recall = 0.0620
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 3s 40ms/step
# Noise STDDEV = 0.84 -> Accuracy = 0.0750, F1 = 0.0265, Precision = 0.0335, Recall = 0.0750
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step
# Noise STDDEV = 0.89 -> Accuracy = 0.0675, F1 = 0.0236, Precision = 0.0540, Recall = 0.0675
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step
# Noise STDDEV = 0.95 -> Accuracy = 0.0635, F1 = 0.0179, Precision = 0.0175, Recall = 0.0635
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step
# Noise STDDEV = 1.00 -> Accuracy = 0.0655, F1 = 0.0227, Precision = 0.0196, Recall = 0.0655
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))

# %%
print(y_reference_list_1)
print(y_reference_probs_list_1)
print(y_pred_noisy_probs_list_1)
print(y_pred_noisy_list_1)
# Out:
# [array([12, 27, 24, ..., 16, 29,  3]), array([12, 27, 24, ..., 16, 29,  3]), array([12, 27, 24, ..., 16, 29,  3]), array([12, 27, 24, ..., 16, 29,  3]), array([12, 27, 24, ..., 16, 29,  3]), array([12, 27, 24, ..., 16, 29,  3]), array([12, 27, 24, ..., 16, 29,  3]), array([12, 27, 24, ..., 16, 29,  3]), array([12, 27, 24, ..., 16, 29,  3]), array([12, 27, 24, ..., 16, 29,  3]), array([12, 27, 24, ..., 16, 29,  3]), array([12, 27, 24, ..., 16, 29,  3]), array([12, 27, 24, ..., 16, 29,  3]), array([12, 27, 24, ..., 16, 29,  3]), array([12, 27, 24, ..., 16, 29,  3]), array([12, 27, 24, ..., 16, 29,  3]), array([12, 27, 24, ..., 16, 29,  3]), array([12, 27, 24, ..., 16, 29,  3]), array([12, 27, 24, ..., 16, 29,  3]), array([12, 27, 24, ..., 16, 29,  3])]
# [array([[1.95420329e-02, 6.40608137e-04, 4.26733721e-04, ...,
#         9.20926034e-03, 1.40126329e-02, 2.08109515e-04],
#        [9.61532118e-04, 2.88252540e-05, 2.25216779e-03, ...,
#         8.47539842e-01, 1.85594676e-04, 1.03395041e-05],
#        [1.33724958e-01, 1.95563858e-04, 3.07480805e-02, ...,
#         1.22915569e-03, 1.40987515e-01, 1.12349257e-01],
#        ...,
#        [9.34603717e-03, 3.09905095e-04, 8.15865770e-03, ...,
#         1.23998694e-01, 6.08620979e-03, 4.31552622e-03],
#        [3.06926165e-02, 1.93019006e-02, 4.20033903e-05, ...,
#         6.37782941e-05, 2.03892894e-04, 4.79699314e-01],
#        [9.51617956e-03, 8.55458551e-04, 4.29943648e-05, ...,
#         8.23602204e-06, 8.86832822e-06, 2.92876803e-06]], dtype=float32), array([[1.95420329e-02, 6.40608137e-04, 4.26733721e-04, ...,
#         9.20926034e-03, 1.40126329e-02, 2.08109515e-04],
#        [9.61532118e-04, 2.88252540e-05, 2.25216779e-03, ...,
#         8.47539842e-01, 1.85594676e-04, 1.03395041e-05],
#        [1.33724958e-01, 1.95563858e-04, 3.07480805e-02, ...,
#         1.22915569e-03, 1.40987515e-01, 1.12349257e-01],
#        ...,
#        [9.34603717e-03, 3.09905095e-04, 8.15865770e-03, ...,
#         1.23998694e-01, 6.08620979e-03, 4.31552622e-03],
#        [3.06926165e-02, 1.93019006e-02, 4.20033903e-05, ...,
#         6.37782941e-05, 2.03892894e-04, 4.79699314e-01],
#        [9.51617956e-03, 8.55458551e-04, 4.29943648e-05, ...,
#         8.23602204e-06, 8.86832822e-06, 2.92876803e-06]], dtype=float32), array([[1.95420329e-02, 6.40608137e-04, 4.26733721e-04, ...,
#         9.20926034e-03, 1.40126329e-02, 2.08109515e-04],
#        [9.61532118e-04, 2.88252540e-05, 2.25216779e-03, ...,
#         8.47539842e-01, 1.85594676e-04, 1.03395041e-05],
#        [1.33724958e-01, 1.95563858e-04, 3.07480805e-02, ...,
#         1.22915569e-03, 1.40987515e-01, 1.12349257e-01],
#        ...,
#        [9.34603717e-03, 3.09905095e-04, 8.15865770e-03, ...,
#         1.23998694e-01, 6.08620979e-03, 4.31552622e-03],
#        [3.06926165e-02, 1.93019006e-02, 4.20033903e-05, ...,
#         6.37782941e-05, 2.03892894e-04, 4.79699314e-01],
#        [9.51617956e-03, 8.55458551e-04, 4.29943648e-05, ...,
#         8.23602204e-06, 8.86832822e-06, 2.92876803e-06]], dtype=float32), array([[1.95420329e-02, 6.40608137e-04, 4.26733721e-04, ...,
#         9.20926034e-03, 1.40126329e-02, 2.08109515e-04],
#        [9.61532118e-04, 2.88252540e-05, 2.25216779e-03, ...,
#         8.47539842e-01, 1.85594676e-04, 1.03395041e-05],
#        [1.33724958e-01, 1.95563858e-04, 3.07480805e-02, ...,
#         1.22915569e-03, 1.40987515e-01, 1.12349257e-01],
#        ...,
#        [9.34603717e-03, 3.09905095e-04, 8.15865770e-03, ...,
#         1.23998694e-01, 6.08620979e-03, 4.31552622e-03],
#        [3.06926165e-02, 1.93019006e-02, 4.20033903e-05, ...,
#         6.37782941e-05, 2.03892894e-04, 4.79699314e-01],
#        [9.51617956e-03, 8.55458551e-04, 4.29943648e-05, ...,
#         8.23602204e-06, 8.86832822e-06, 2.92876803e-06]], dtype=float32), array([[1.95420329e-02, 6.40608137e-04, 4.26733721e-04, ...,
#         9.20926034e-03, 1.40126329e-02, 2.08109515e-04],
#        [9.61532118e-04, 2.88252540e-05, 2.25216779e-03, ...,
#         8.47539842e-01, 1.85594676e-04, 1.03395041e-05],
#        [1.33724958e-01, 1.95563858e-04, 3.07480805e-02, ...,
#         1.22915569e-03, 1.40987515e-01, 1.12349257e-01],
#        ...,
#        [9.34603717e-03, 3.09905095e-04, 8.15865770e-03, ...,
#         1.23998694e-01, 6.08620979e-03, 4.31552622e-03],
#        [3.06926165e-02, 1.93019006e-02, 4.20033903e-05, ...,
#         6.37782941e-05, 2.03892894e-04, 4.79699314e-01],
#        [9.51617956e-03, 8.55458551e-04, 4.29943648e-05, ...,
#         8.23602204e-06, 8.86832822e-06, 2.92876803e-06]], dtype=float32), array([[1.95420329e-02, 6.40608137e-04, 4.26733721e-04, ...,
#         9.20926034e-03, 1.40126329e-02, 2.08109515e-04],
#        [9.61532118e-04, 2.88252540e-05, 2.25216779e-03, ...,
#         8.47539842e-01, 1.85594676e-04, 1.03395041e-05],
#        [1.33724958e-01, 1.95563858e-04, 3.07480805e-02, ...,
#         1.22915569e-03, 1.40987515e-01, 1.12349257e-01],
#        ...,
#        [9.34603717e-03, 3.09905095e-04, 8.15865770e-03, ...,
#         1.23998694e-01, 6.08620979e-03, 4.31552622e-03],
#        [3.06926165e-02, 1.93019006e-02, 4.20033903e-05, ...,
#         6.37782941e-05, 2.03892894e-04, 4.79699314e-01],
#        [9.51617956e-03, 8.55458551e-04, 4.29943648e-05, ...,
#         8.23602204e-06, 8.86832822e-06, 2.92876803e-06]], dtype=float32), array([[1.95420329e-02, 6.40608137e-04, 4.26733721e-04, ...,
#         9.20926034e-03, 1.40126329e-02, 2.08109515e-04],
#        [9.61532118e-04, 2.88252540e-05, 2.25216779e-03, ...,
#         8.47539842e-01, 1.85594676e-04, 1.03395041e-05],
#        [1.33724958e-01, 1.95563858e-04, 3.07480805e-02, ...,
#         1.22915569e-03, 1.40987515e-01, 1.12349257e-01],
#        ...,
#        [9.34603717e-03, 3.09905095e-04, 8.15865770e-03, ...,
#         1.23998694e-01, 6.08620979e-03, 4.31552622e-03],
#        [3.06926165e-02, 1.93019006e-02, 4.20033903e-05, ...,
#         6.37782941e-05, 2.03892894e-04, 4.79699314e-01],
#        [9.51617956e-03, 8.55458551e-04, 4.29943648e-05, ...,
#         8.23602204e-06, 8.86832822e-06, 2.92876803e-06]], dtype=float32), array([[1.95420329e-02, 6.40608137e-04, 4.26733721e-04, ...,
#         9.20926034e-03, 1.40126329e-02, 2.08109515e-04],
#        [9.61532118e-04, 2.88252540e-05, 2.25216779e-03, ...,
#         8.47539842e-01, 1.85594676e-04, 1.03395041e-05],
#        [1.33724958e-01, 1.95563858e-04, 3.07480805e-02, ...,
#         1.22915569e-03, 1.40987515e-01, 1.12349257e-01],
#        ...,
#        [9.34603717e-03, 3.09905095e-04, 8.15865770e-03, ...,
#         1.23998694e-01, 6.08620979e-03, 4.31552622e-03],
#        [3.06926165e-02, 1.93019006e-02, 4.20033903e-05, ...,
#         6.37782941e-05, 2.03892894e-04, 4.79699314e-01],
#        [9.51617956e-03, 8.55458551e-04, 4.29943648e-05, ...,
#         8.23602204e-06, 8.86832822e-06, 2.92876803e-06]], dtype=float32), array([[1.95420329e-02, 6.40608137e-04, 4.26733721e-04, ...,
#         9.20926034e-03, 1.40126329e-02, 2.08109515e-04],
#        [9.61532118e-04, 2.88252540e-05, 2.25216779e-03, ...,
#         8.47539842e-01, 1.85594676e-04, 1.03395041e-05],
#        [1.33724958e-01, 1.95563858e-04, 3.07480805e-02, ...,
#         1.22915569e-03, 1.40987515e-01, 1.12349257e-01],
#        ...,
#        [9.34603717e-03, 3.09905095e-04, 8.15865770e-03, ...,
#         1.23998694e-01, 6.08620979e-03, 4.31552622e-03],
#        [3.06926165e-02, 1.93019006e-02, 4.20033903e-05, ...,
#         6.37782941e-05, 2.03892894e-04, 4.79699314e-01],
#        [9.51617956e-03, 8.55458551e-04, 4.29943648e-05, ...,
#         8.23602204e-06, 8.86832822e-06, 2.92876803e-06]], dtype=float32), array([[1.95420329e-02, 6.40608137e-04, 4.26733721e-04, ...,
#         9.20926034e-03, 1.40126329e-02, 2.08109515e-04],
#        [9.61532118e-04, 2.88252540e-05, 2.25216779e-03, ...,
#         8.47539842e-01, 1.85594676e-04, 1.03395041e-05],
#        [1.33724958e-01, 1.95563858e-04, 3.07480805e-02, ...,
#         1.22915569e-03, 1.40987515e-01, 1.12349257e-01],
#        ...,
#        [9.34603717e-03, 3.09905095e-04, 8.15865770e-03, ...,
#         1.23998694e-01, 6.08620979e-03, 4.31552622e-03],
#        [3.06926165e-02, 1.93019006e-02, 4.20033903e-05, ...,
#         6.37782941e-05, 2.03892894e-04, 4.79699314e-01],
#        [9.51617956e-03, 8.55458551e-04, 4.29943648e-05, ...,
#         8.23602204e-06, 8.86832822e-06, 2.92876803e-06]], dtype=float32), array([[1.95420329e-02, 6.40608137e-04, 4.26733721e-04, ...,
#         9.20926034e-03, 1.40126329e-02, 2.08109515e-04],
#        [9.61532118e-04, 2.88252540e-05, 2.25216779e-03, ...,
#         8.47539842e-01, 1.85594676e-04, 1.03395041e-05],
#        [1.33724958e-01, 1.95563858e-04, 3.07480805e-02, ...,
#         1.22915569e-03, 1.40987515e-01, 1.12349257e-01],
#        ...,
#        [9.34603717e-03, 3.09905095e-04, 8.15865770e-03, ...,
#         1.23998694e-01, 6.08620979e-03, 4.31552622e-03],
#        [3.06926165e-02, 1.93019006e-02, 4.20033903e-05, ...,
#         6.37782941e-05, 2.03892894e-04, 4.79699314e-01],
#        [9.51617956e-03, 8.55458551e-04, 4.29943648e-05, ...,
#         8.23602204e-06, 8.86832822e-06, 2.92876803e-06]], dtype=float32), array([[1.95420329e-02, 6.40608137e-04, 4.26733721e-04, ...,
#         9.20926034e-03, 1.40126329e-02, 2.08109515e-04],
#        [9.61532118e-04, 2.88252540e-05, 2.25216779e-03, ...,
#         8.47539842e-01, 1.85594676e-04, 1.03395041e-05],
#        [1.33724958e-01, 1.95563858e-04, 3.07480805e-02, ...,
#         1.22915569e-03, 1.40987515e-01, 1.12349257e-01],
#        ...,
#        [9.34603717e-03, 3.09905095e-04, 8.15865770e-03, ...,
#         1.23998694e-01, 6.08620979e-03, 4.31552622e-03],
#        [3.06926165e-02, 1.93019006e-02, 4.20033903e-05, ...,
#         6.37782941e-05, 2.03892894e-04, 4.79699314e-01],
#        [9.51617956e-03, 8.55458551e-04, 4.29943648e-05, ...,
#         8.23602204e-06, 8.86832822e-06, 2.92876803e-06]], dtype=float32), array([[1.95420329e-02, 6.40608137e-04, 4.26733721e-04, ...,
#         9.20926034e-03, 1.40126329e-02, 2.08109515e-04],
#        [9.61532118e-04, 2.88252540e-05, 2.25216779e-03, ...,
#         8.47539842e-01, 1.85594676e-04, 1.03395041e-05],
#        [1.33724958e-01, 1.95563858e-04, 3.07480805e-02, ...,
#         1.22915569e-03, 1.40987515e-01, 1.12349257e-01],
#        ...,
#        [9.34603717e-03, 3.09905095e-04, 8.15865770e-03, ...,
#         1.23998694e-01, 6.08620979e-03, 4.31552622e-03],
#        [3.06926165e-02, 1.93019006e-02, 4.20033903e-05, ...,
#         6.37782941e-05, 2.03892894e-04, 4.79699314e-01],
#        [9.51617956e-03, 8.55458551e-04, 4.29943648e-05, ...,
#         8.23602204e-06, 8.86832822e-06, 2.92876803e-06]], dtype=float32), array([[1.95420329e-02, 6.40608137e-04, 4.26733721e-04, ...,
#         9.20926034e-03, 1.40126329e-02, 2.08109515e-04],
#        [9.61532118e-04, 2.88252540e-05, 2.25216779e-03, ...,
#         8.47539842e-01, 1.85594676e-04, 1.03395041e-05],
#        [1.33724958e-01, 1.95563858e-04, 3.07480805e-02, ...,
#         1.22915569e-03, 1.40987515e-01, 1.12349257e-01],
#        ...,
#        [9.34603717e-03, 3.09905095e-04, 8.15865770e-03, ...,
#         1.23998694e-01, 6.08620979e-03, 4.31552622e-03],
#        [3.06926165e-02, 1.93019006e-02, 4.20033903e-05, ...,
#         6.37782941e-05, 2.03892894e-04, 4.79699314e-01],
#        [9.51617956e-03, 8.55458551e-04, 4.29943648e-05, ...,
#         8.23602204e-06, 8.86832822e-06, 2.92876803e-06]], dtype=float32), array([[1.95420329e-02, 6.40608137e-04, 4.26733721e-04, ...,
#         9.20926034e-03, 1.40126329e-02, 2.08109515e-04],
#        [9.61532118e-04, 2.88252540e-05, 2.25216779e-03, ...,
#         8.47539842e-01, 1.85594676e-04, 1.03395041e-05],
#        [1.33724958e-01, 1.95563858e-04, 3.07480805e-02, ...,
#         1.22915569e-03, 1.40987515e-01, 1.12349257e-01],
#        ...,
#        [9.34603717e-03, 3.09905095e-04, 8.15865770e-03, ...,
#         1.23998694e-01, 6.08620979e-03, 4.31552622e-03],
#        [3.06926165e-02, 1.93019006e-02, 4.20033903e-05, ...,
#         6.37782941e-05, 2.03892894e-04, 4.79699314e-01],
#        [9.51617956e-03, 8.55458551e-04, 4.29943648e-05, ...,
#         8.23602204e-06, 8.86832822e-06, 2.92876803e-06]], dtype=float32), array([[1.95420329e-02, 6.40608137e-04, 4.26733721e-04, ...,
#         9.20926034e-03, 1.40126329e-02, 2.08109515e-04],
#        [9.61532118e-04, 2.88252540e-05, 2.25216779e-03, ...,
#         8.47539842e-01, 1.85594676e-04, 1.03395041e-05],
#        [1.33724958e-01, 1.95563858e-04, 3.07480805e-02, ...,
#         1.22915569e-03, 1.40987515e-01, 1.12349257e-01],
#        ...,
#        [9.34603717e-03, 3.09905095e-04, 8.15865770e-03, ...,
#         1.23998694e-01, 6.08620979e-03, 4.31552622e-03],
#        [3.06926165e-02, 1.93019006e-02, 4.20033903e-05, ...,
#         6.37782941e-05, 2.03892894e-04, 4.79699314e-01],
#        [9.51617956e-03, 8.55458551e-04, 4.29943648e-05, ...,
#         8.23602204e-06, 8.86832822e-06, 2.92876803e-06]], dtype=float32), array([[1.95420329e-02, 6.40608137e-04, 4.26733721e-04, ...,
#         9.20926034e-03, 1.40126329e-02, 2.08109515e-04],
#        [9.61532118e-04, 2.88252540e-05, 2.25216779e-03, ...,
#         8.47539842e-01, 1.85594676e-04, 1.03395041e-05],
#        [1.33724958e-01, 1.95563858e-04, 3.07480805e-02, ...,
#         1.22915569e-03, 1.40987515e-01, 1.12349257e-01],
#        ...,
#        [9.34603717e-03, 3.09905095e-04, 8.15865770e-03, ...,
#         1.23998694e-01, 6.08620979e-03, 4.31552622e-03],
#        [3.06926165e-02, 1.93019006e-02, 4.20033903e-05, ...,
#         6.37782941e-05, 2.03892894e-04, 4.79699314e-01],
#        [9.51617956e-03, 8.55458551e-04, 4.29943648e-05, ...,
#         8.23602204e-06, 8.86832822e-06, 2.92876803e-06]], dtype=float32), array([[1.95420329e-02, 6.40608137e-04, 4.26733721e-04, ...,
#         9.20926034e-03, 1.40126329e-02, 2.08109515e-04],
#        [9.61532118e-04, 2.88252540e-05, 2.25216779e-03, ...,
#         8.47539842e-01, 1.85594676e-04, 1.03395041e-05],
#        [1.33724958e-01, 1.95563858e-04, 3.07480805e-02, ...,
#         1.22915569e-03, 1.40987515e-01, 1.12349257e-01],
#        ...,
#        [9.34603717e-03, 3.09905095e-04, 8.15865770e-03, ...,
#         1.23998694e-01, 6.08620979e-03, 4.31552622e-03],
#        [3.06926165e-02, 1.93019006e-02, 4.20033903e-05, ...,
#         6.37782941e-05, 2.03892894e-04, 4.79699314e-01],
#        [9.51617956e-03, 8.55458551e-04, 4.29943648e-05, ...,
#         8.23602204e-06, 8.86832822e-06, 2.92876803e-06]], dtype=float32), array([[1.95420329e-02, 6.40608137e-04, 4.26733721e-04, ...,
#         9.20926034e-03, 1.40126329e-02, 2.08109515e-04],
#        [9.61532118e-04, 2.88252540e-05, 2.25216779e-03, ...,
#         8.47539842e-01, 1.85594676e-04, 1.03395041e-05],
#        [1.33724958e-01, 1.95563858e-04, 3.07480805e-02, ...,
#         1.22915569e-03, 1.40987515e-01, 1.12349257e-01],
#        ...,
#        [9.34603717e-03, 3.09905095e-04, 8.15865770e-03, ...,
#         1.23998694e-01, 6.08620979e-03, 4.31552622e-03],
#        [3.06926165e-02, 1.93019006e-02, 4.20033903e-05, ...,
#         6.37782941e-05, 2.03892894e-04, 4.79699314e-01],
#        [9.51617956e-03, 8.55458551e-04, 4.29943648e-05, ...,
#         8.23602204e-06, 8.86832822e-06, 2.92876803e-06]], dtype=float32), array([[1.95420329e-02, 6.40608137e-04, 4.26733721e-04, ...,
#         9.20926034e-03, 1.40126329e-02, 2.08109515e-04],
#        [9.61532118e-04, 2.88252540e-05, 2.25216779e-03, ...,
#         8.47539842e-01, 1.85594676e-04, 1.03395041e-05],
#        [1.33724958e-01, 1.95563858e-04, 3.07480805e-02, ...,
#         1.22915569e-03, 1.40987515e-01, 1.12349257e-01],
#        ...,
#        [9.34603717e-03, 3.09905095e-04, 8.15865770e-03, ...,
#         1.23998694e-01, 6.08620979e-03, 4.31552622e-03],
#        [3.06926165e-02, 1.93019006e-02, 4.20033903e-05, ...,
#         6.37782941e-05, 2.03892894e-04, 4.79699314e-01],
#        [9.51617956e-03, 8.55458551e-04, 4.29943648e-05, ...,
#         8.23602204e-06, 8.86832822e-06, 2.92876803e-06]], dtype=float32)]
# [array([[1.95420329e-02, 6.40608137e-04, 4.26733721e-04, ...,
#         9.20926034e-03, 1.40126329e-02, 2.08109515e-04],
#        [9.61532118e-04, 2.88252540e-05, 2.25216779e-03, ...,
#         8.47539842e-01, 1.85594676e-04, 1.03395041e-05],
#        [1.33724958e-01, 1.95563858e-04, 3.07480805e-02, ...,
#         1.22915569e-03, 1.40987515e-01, 1.12349257e-01],
#        ...,
#        [9.34603717e-03, 3.09905095e-04, 8.15865770e-03, ...,
#         1.23998694e-01, 6.08620979e-03, 4.31552622e-03],
#        [3.06926165e-02, 1.93019006e-02, 4.20033903e-05, ...,
#         6.37782941e-05, 2.03892894e-04, 4.79699314e-01],
#        [9.51617956e-03, 8.55458551e-04, 4.29943648e-05, ...,
#         8.23602204e-06, 8.86832822e-06, 2.92876803e-06]], dtype=float32), array([[1.7209522e-02, 6.7917560e-04, 4.2273552e-04, ..., 7.5770370e-03,
#         8.2929963e-03, 2.1252991e-04],
#        [3.55247268e-03, 4.29210020e-04, 4.49238250e-05, ...,
#         8.63857043e-04, 2.05994071e-03, 9.05186636e-04],
#        ...,
#        [1.19044795e-03, 2.26419274e-04, 8.59927150e-06, ...,
#         7.51128755e-05, 1.42271252e-04, 9.95036587e-03],
#        [1.08718849e-03, 3.74513475e-04, 6.51383334e-06, ...,
#         1.40697943e-04, 7.02569843e-04, 2.51375558e-03],
#        [7.03483995e-04, 3.07025475e-04, 1.09732155e-05, ...,
#         8.85579357e-05, 1.80715043e-03, 2.01604981e-03]], dtype=float32)]
# [array([12, 27, 24, ..., 16, 29,  3]), array([12, 27, 24, ..., 16, 29,  3]), array([12, 16, 26, ..., 24, 29, 15]), array([12, 24, 26, ..., 15, 29, 15]), array([ 5, 24, 26, ...,  7,  8, 15]), array([12, 24, 12, ..., 24,  8, 15]), array([12, 24, 29, ...,  8,  8, 15]), array([12, 24, 21, ...,  8,  8,  8]), array([12,  7,  8, ...,  8,  8,  8]), array([12, 11, 12, ...,  8,  8,  8]), array([12,  8,  8, ...,  8,  8,  8]), array([ 8,  8,  8, ..., 24,  8,  8]), array([21,  8,  8, ..., 12,  8,  8]), array([ 8, 11,  8, ...,  8,  8,  8]), array([21,  8,  8, ..., 12,  8,  8]), array([8, 8, 8, ..., 8, 8, 8]), array([11, 11,  8, ...,  8,  8,  8]), array([12,  8,  8, ...,  8,  8, 24]), array([8, 8, 8, ..., 8, 8, 8]), array([ 8, 11,  8, ...,  8,  8,  8])]

# %%
print(y_reference_list)
print(y_reference_probs_list)
print(y_pred_noisy_probs_list)
print(y_pred_noisy_list)
# Out:
# [array([ 5, 27, 28, ..., 27, 29,  3]), array([ 5, 27, 28, ..., 27, 29,  3]), array([ 5, 27, 28, ..., 27, 29,  3]), array([ 5, 27, 28, ..., 27, 29,  3]), array([ 5, 27, 28, ..., 27, 29,  3]), array([ 5, 27, 28, ..., 27, 29,  3]), array([ 5, 27, 28, ..., 27, 29,  3]), array([ 5, 27, 28, ..., 27, 29,  3]), array([ 5, 27, 28, ..., 27, 29,  3]), array([ 5, 27, 28, ..., 27, 29,  3]), array([ 5, 27, 28, ..., 27, 29,  3]), array([ 5, 27, 28, ..., 27, 29,  3]), array([ 5, 27, 28, ..., 27, 29,  3]), array([ 5, 27, 28, ..., 27, 29,  3]), array([ 5, 27, 28, ..., 27, 29,  3]), array([ 5, 27, 28, ..., 27, 29,  3]), array([ 5, 27, 28, ..., 27, 29,  3]), array([ 5, 27, 28, ..., 27, 29,  3]), array([ 5, 27, 28, ..., 27, 29,  3]), array([ 5, 27, 28, ..., 27, 29,  3])]
# [array([[2.03824490e-02, 1.67230645e-03, 3.28308460e-03, ...,
#         1.21595897e-02, 3.65753584e-02, 5.86824317e-04],
#        [2.82408932e-04, 2.22162740e-07, 1.86388046e-04, ...,
#         3.34154338e-01, 2.85636797e-03, 4.03860431e-05],
#        [4.24237065e-02, 4.01532234e-05, 1.30740404e-02, ...,
#         5.39906323e-03, 4.73838568e-01, 1.76659357e-02],
#        ...,
#        [4.37680595e-02, 6.92549685e-04, 5.40805794e-03, ...,
#         2.40870997e-01, 1.62807237e-02, 9.23176110e-03],
#        [1.64203748e-01, 8.49579349e-02, 8.42742505e-04, ...,
#         1.26757595e-05, 3.07490482e-05, 3.15266132e-01],
#        [4.61774645e-03, 4.00386658e-03, 2.95482352e-02, ...,
#         1.03110062e-04, 5.50522469e-04, 3.24757770e-04]], dtype=float32), array([[2.03824490e-02, 1.67230645e-03, 3.28308460e-03, ...,
#         1.21595897e-02, 3.65753584e-02, 5.86824317e-04],
#        [2.82408932e-04, 2.22162740e-07, 1.86388046e-04, ...,
#         3.34154338e-01, 2.85636797e-03, 4.03860431e-05],
#        [4.24237065e-02, 4.01532234e-05, 1.30740404e-02, ...,
#         5.39906323e-03, 4.73838568e-01, 1.76659357e-02],
#        ...,
#        [4.37680595e-02, 6.92549685e-04, 5.40805794e-03, ...,
#         2.40870997e-01, 1.62807237e-02, 9.23176110e-03],
#        [1.64203748e-01, 8.49579349e-02, 8.42742505e-04, ...,
#         1.26757595e-05, 3.07490482e-05, 3.15266132e-01],
#        [4.61774645e-03, 4.00386658e-03, 2.95482352e-02, ...,
#         1.03110062e-04, 5.50522469e-04, 3.24757770e-04]], dtype=float32), array([[2.03824490e-02, 1.67230645e-03, 3.28308460e-03, ...,
#         1.21595897e-02, 3.65753584e-02, 5.86824317e-04],
#        [2.82408932e-04, 2.22162740e-07, 1.86388046e-04, ...,
#         3.34154338e-01, 2.85636797e-03, 4.03860431e-05],
#        [4.24237065e-02, 4.01532234e-05, 1.30740404e-02, ...,
#         5.39906323e-03, 4.73838568e-01, 1.76659357e-02],
#        ...,
#        [4.37680595e-02, 6.92549685e-04, 5.40805794e-03, ...,
#         2.40870997e-01, 1.62807237e-02, 9.23176110e-03],
#        [1.64203748e-01, 8.49579349e-02, 8.42742505e-04, ...,
#         1.26757595e-05, 3.07490482e-05, 3.15266132e-01],
#        [4.61774645e-03, 4.00386658e-03, 2.95482352e-02, ...,
#         1.03110062e-04, 5.50522469e-04, 3.24757770e-04]], dtype=float32), array([[2.03824490e-02, 1.67230645e-03, 3.28308460e-03, ...,
#         1.21595897e-02, 3.65753584e-02, 5.86824317e-04],
#        [2.82408932e-04, 2.22162740e-07, 1.86388046e-04, ...,
#         3.34154338e-01, 2.85636797e-03, 4.03860431e-05],
#        [4.24237065e-02, 4.01532234e-05, 1.30740404e-02, ...,
#         5.39906323e-03, 4.73838568e-01, 1.76659357e-02],
#        ...,
#        [4.37680595e-02, 6.92549685e-04, 5.40805794e-03, ...,
#         2.40870997e-01, 1.62807237e-02, 9.23176110e-03],
#        [1.64203748e-01, 8.49579349e-02, 8.42742505e-04, ...,
#         1.26757595e-05, 3.07490482e-05, 3.15266132e-01],
#        [4.61774645e-03, 4.00386658e-03, 2.95482352e-02, ...,
#         1.03110062e-04, 5.50522469e-04, 3.24757770e-04]], dtype=float32), array([[2.03824490e-02, 1.67230645e-03, 3.28308460e-03, ...,
#         1.21595897e-02, 3.65753584e-02, 5.86824317e-04],
#        [2.82408932e-04, 2.22162740e-07, 1.86388046e-04, ...,
#         3.34154338e-01, 2.85636797e-03, 4.03860431e-05],
#        [4.24237065e-02, 4.01532234e-05, 1.30740404e-02, ...,
#         5.39906323e-03, 4.73838568e-01, 1.76659357e-02],
#        ...,
#        [4.37680595e-02, 6.92549685e-04, 5.40805794e-03, ...,
#         2.40870997e-01, 1.62807237e-02, 9.23176110e-03],
#        [1.64203748e-01, 8.49579349e-02, 8.42742505e-04, ...,
#         1.26757595e-05, 3.07490482e-05, 3.15266132e-01],
#        [4.61774645e-03, 4.00386658e-03, 2.95482352e-02, ...,
#         1.03110062e-04, 5.50522469e-04, 3.24757770e-04]], dtype=float32), array([[2.03824490e-02, 1.67230645e-03, 3.28308460e-03, ...,
#         1.21595897e-02, 3.65753584e-02, 5.86824317e-04],
#        [2.82408932e-04, 2.22162740e-07, 1.86388046e-04, ...,
#         3.34154338e-01, 2.85636797e-03, 4.03860431e-05],
#        [4.24237065e-02, 4.01532234e-05, 1.30740404e-02, ...,
#         5.39906323e-03, 4.73838568e-01, 1.76659357e-02],
#        ...,
#        [4.37680595e-02, 6.92549685e-04, 5.40805794e-03, ...,
#         2.40870997e-01, 1.62807237e-02, 9.23176110e-03],
#        [1.64203748e-01, 8.49579349e-02, 8.42742505e-04, ...,
#         1.26757595e-05, 3.07490482e-05, 3.15266132e-01],
#        [4.61774645e-03, 4.00386658e-03, 2.95482352e-02, ...,
#         1.03110062e-04, 5.50522469e-04, 3.24757770e-04]], dtype=float32), array([[2.03824490e-02, 1.67230645e-03, 3.28308460e-03, ...,
#         1.21595897e-02, 3.65753584e-02, 5.86824317e-04],
#        [2.82408932e-04, 2.22162740e-07, 1.86388046e-04, ...,
#         3.34154338e-01, 2.85636797e-03, 4.03860431e-05],
#        [4.24237065e-02, 4.01532234e-05, 1.30740404e-02, ...,
#         5.39906323e-03, 4.73838568e-01, 1.76659357e-02],
#        ...,
#        [4.37680595e-02, 6.92549685e-04, 5.40805794e-03, ...,
#         2.40870997e-01, 1.62807237e-02, 9.23176110e-03],
#        [1.64203748e-01, 8.49579349e-02, 8.42742505e-04, ...,
#         1.26757595e-05, 3.07490482e-05, 3.15266132e-01],
#        [4.61774645e-03, 4.00386658e-03, 2.95482352e-02, ...,
#         1.03110062e-04, 5.50522469e-04, 3.24757770e-04]], dtype=float32), array([[2.03824490e-02, 1.67230645e-03, 3.28308460e-03, ...,
#         1.21595897e-02, 3.65753584e-02, 5.86824317e-04],
#        [2.82408932e-04, 2.22162740e-07, 1.86388046e-04, ...,
#         3.34154338e-01, 2.85636797e-03, 4.03860431e-05],
#        [4.24237065e-02, 4.01532234e-05, 1.30740404e-02, ...,
#         5.39906323e-03, 4.73838568e-01, 1.76659357e-02],
#        ...,
#        [4.37680595e-02, 6.92549685e-04, 5.40805794e-03, ...,
#         2.40870997e-01, 1.62807237e-02, 9.23176110e-03],
#        [1.64203748e-01, 8.49579349e-02, 8.42742505e-04, ...,
#         1.26757595e-05, 3.07490482e-05, 3.15266132e-01],
#        [4.61774645e-03, 4.00386658e-03, 2.95482352e-02, ...,
#         1.03110062e-04, 5.50522469e-04, 3.24757770e-04]], dtype=float32), array([[2.03824490e-02, 1.67230645e-03, 3.28308460e-03, ...,
#         1.21595897e-02, 3.65753584e-02, 5.86824317e-04],
#        [2.82408932e-04, 2.22162740e-07, 1.86388046e-04, ...,
#         3.34154338e-01, 2.85636797e-03, 4.03860431e-05],
#        [4.24237065e-02, 4.01532234e-05, 1.30740404e-02, ...,
#         5.39906323e-03, 4.73838568e-01, 1.76659357e-02],
#        ...,
#        [4.37680595e-02, 6.92549685e-04, 5.40805794e-03, ...,
#         2.40870997e-01, 1.62807237e-02, 9.23176110e-03],
#        [1.64203748e-01, 8.49579349e-02, 8.42742505e-04, ...,
#         1.26757595e-05, 3.07490482e-05, 3.15266132e-01],
#        [4.61774645e-03, 4.00386658e-03, 2.95482352e-02, ...,
#         1.03110062e-04, 5.50522469e-04, 3.24757770e-04]], dtype=float32), array([[2.03824490e-02, 1.67230645e-03, 3.28308460e-03, ...,
#         1.21595897e-02, 3.65753584e-02, 5.86824317e-04],
#        [2.82408932e-04, 2.22162740e-07, 1.86388046e-04, ...,
#         3.34154338e-01, 2.85636797e-03, 4.03860431e-05],
#        [4.24237065e-02, 4.01532234e-05, 1.30740404e-02, ...,
#         5.39906323e-03, 4.73838568e-01, 1.76659357e-02],
#        ...,
#        [4.37680595e-02, 6.92549685e-04, 5.40805794e-03, ...,
#         2.40870997e-01, 1.62807237e-02, 9.23176110e-03],
#        [1.64203748e-01, 8.49579349e-02, 8.42742505e-04, ...,
#         1.26757595e-05, 3.07490482e-05, 3.15266132e-01],
#        [4.61774645e-03, 4.00386658e-03, 2.95482352e-02, ...,
#         1.03110062e-04, 5.50522469e-04, 3.24757770e-04]], dtype=float32), array([[2.03824490e-02, 1.67230645e-03, 3.28308460e-03, ...,
#         1.21595897e-02, 3.65753584e-02, 5.86824317e-04],
#        [2.82408932e-04, 2.22162740e-07, 1.86388046e-04, ...,
#         3.34154338e-01, 2.85636797e-03, 4.03860431e-05],
#        [4.24237065e-02, 4.01532234e-05, 1.30740404e-02, ...,
#         5.39906323e-03, 4.73838568e-01, 1.76659357e-02],
#        ...,
#        [4.37680595e-02, 6.92549685e-04, 5.40805794e-03, ...,
#         2.40870997e-01, 1.62807237e-02, 9.23176110e-03],
#        [1.64203748e-01, 8.49579349e-02, 8.42742505e-04, ...,
#         1.26757595e-05, 3.07490482e-05, 3.15266132e-01],
#        [4.61774645e-03, 4.00386658e-03, 2.95482352e-02, ...,
#         1.03110062e-04, 5.50522469e-04, 3.24757770e-04]], dtype=float32), array([[2.03824490e-02, 1.67230645e-03, 3.28308460e-03, ...,
#         1.21595897e-02, 3.65753584e-02, 5.86824317e-04],
#        [2.82408932e-04, 2.22162740e-07, 1.86388046e-04, ...,
#         3.34154338e-01, 2.85636797e-03, 4.03860431e-05],
#        [4.24237065e-02, 4.01532234e-05, 1.30740404e-02, ...,
#         5.39906323e-03, 4.73838568e-01, 1.76659357e-02],
#        ...,
#        [4.37680595e-02, 6.92549685e-04, 5.40805794e-03, ...,
#         2.40870997e-01, 1.62807237e-02, 9.23176110e-03],
#        [1.64203748e-01, 8.49579349e-02, 8.42742505e-04, ...,
#         1.26757595e-05, 3.07490482e-05, 3.15266132e-01],
#        [4.61774645e-03, 4.00386658e-03, 2.95482352e-02, ...,
#         1.03110062e-04, 5.50522469e-04, 3.24757770e-04]], dtype=float32), array([[2.03824490e-02, 1.67230645e-03, 3.28308460e-03, ...,
#         1.21595897e-02, 3.65753584e-02, 5.86824317e-04],
#        [2.82408932e-04, 2.22162740e-07, 1.86388046e-04, ...,
#         3.34154338e-01, 2.85636797e-03, 4.03860431e-05],
#        [4.24237065e-02, 4.01532234e-05, 1.30740404e-02, ...,
#         5.39906323e-03, 4.73838568e-01, 1.76659357e-02],
#        ...,
#        [4.37680595e-02, 6.92549685e-04, 5.40805794e-03, ...,
#         2.40870997e-01, 1.62807237e-02, 9.23176110e-03],
#        [1.64203748e-01, 8.49579349e-02, 8.42742505e-04, ...,
#         1.26757595e-05, 3.07490482e-05, 3.15266132e-01],
#        [4.61774645e-03, 4.00386658e-03, 2.95482352e-02, ...,
#         1.03110062e-04, 5.50522469e-04, 3.24757770e-04]], dtype=float32), array([[2.03824490e-02, 1.67230645e-03, 3.28308460e-03, ...,
#         1.21595897e-02, 3.65753584e-02, 5.86824317e-04],
#        [2.82408932e-04, 2.22162740e-07, 1.86388046e-04, ...,
#         3.34154338e-01, 2.85636797e-03, 4.03860431e-05],
#        [4.24237065e-02, 4.01532234e-05, 1.30740404e-02, ...,
#         5.39906323e-03, 4.73838568e-01, 1.76659357e-02],
#        ...,
#        [4.37680595e-02, 6.92549685e-04, 5.40805794e-03, ...,
#         2.40870997e-01, 1.62807237e-02, 9.23176110e-03],
#        [1.64203748e-01, 8.49579349e-02, 8.42742505e-04, ...,
#         1.26757595e-05, 3.07490482e-05, 3.15266132e-01],
#        [4.61774645e-03, 4.00386658e-03, 2.95482352e-02, ...,
#         1.03110062e-04, 5.50522469e-04, 3.24757770e-04]], dtype=float32), array([[2.03824490e-02, 1.67230645e-03, 3.28308460e-03, ...,
#         1.21595897e-02, 3.65753584e-02, 5.86824317e-04],
#        [2.82408932e-04, 2.22162740e-07, 1.86388046e-04, ...,
#         3.34154338e-01, 2.85636797e-03, 4.03860431e-05],
#        [4.24237065e-02, 4.01532234e-05, 1.30740404e-02, ...,
#         5.39906323e-03, 4.73838568e-01, 1.76659357e-02],
#        ...,
#        [4.37680595e-02, 6.92549685e-04, 5.40805794e-03, ...,
#         2.40870997e-01, 1.62807237e-02, 9.23176110e-03],
#        [1.64203748e-01, 8.49579349e-02, 8.42742505e-04, ...,
#         1.26757595e-05, 3.07490482e-05, 3.15266132e-01],
#        [4.61774645e-03, 4.00386658e-03, 2.95482352e-02, ...,
#         1.03110062e-04, 5.50522469e-04, 3.24757770e-04]], dtype=float32), array([[2.03824490e-02, 1.67230645e-03, 3.28308460e-03, ...,
#         1.21595897e-02, 3.65753584e-02, 5.86824317e-04],
#        [2.82408932e-04, 2.22162740e-07, 1.86388046e-04, ...,
#         3.34154338e-01, 2.85636797e-03, 4.03860431e-05],
#        [4.24237065e-02, 4.01532234e-05, 1.30740404e-02, ...,
#         5.39906323e-03, 4.73838568e-01, 1.76659357e-02],
#        ...,
#        [4.37680595e-02, 6.92549685e-04, 5.40805794e-03, ...,
#         2.40870997e-01, 1.62807237e-02, 9.23176110e-03],
#        [1.64203748e-01, 8.49579349e-02, 8.42742505e-04, ...,
#         1.26757595e-05, 3.07490482e-05, 3.15266132e-01],
#        [4.61774645e-03, 4.00386658e-03, 2.95482352e-02, ...,
#         1.03110062e-04, 5.50522469e-04, 3.24757770e-04]], dtype=float32), array([[2.03824490e-02, 1.67230645e-03, 3.28308460e-03, ...,
#         1.21595897e-02, 3.65753584e-02, 5.86824317e-04],
#        [2.82408932e-04, 2.22162740e-07, 1.86388046e-04, ...,
#         3.34154338e-01, 2.85636797e-03, 4.03860431e-05],
#        [4.24237065e-02, 4.01532234e-05, 1.30740404e-02, ...,
#         5.39906323e-03, 4.73838568e-01, 1.76659357e-02],
#        ...,
#        [4.37680595e-02, 6.92549685e-04, 5.40805794e-03, ...,
#         2.40870997e-01, 1.62807237e-02, 9.23176110e-03],
#        [1.64203748e-01, 8.49579349e-02, 8.42742505e-04, ...,
#         1.26757595e-05, 3.07490482e-05, 3.15266132e-01],
#        [4.61774645e-03, 4.00386658e-03, 2.95482352e-02, ...,
#         1.03110062e-04, 5.50522469e-04, 3.24757770e-04]], dtype=float32), array([[2.03824490e-02, 1.67230645e-03, 3.28308460e-03, ...,
#         1.21595897e-02, 3.65753584e-02, 5.86824317e-04],
#        [2.82408932e-04, 2.22162740e-07, 1.86388046e-04, ...,
#         3.34154338e-01, 2.85636797e-03, 4.03860431e-05],
#        [4.24237065e-02, 4.01532234e-05, 1.30740404e-02, ...,
#         5.39906323e-03, 4.73838568e-01, 1.76659357e-02],
#        ...,
#        [4.37680595e-02, 6.92549685e-04, 5.40805794e-03, ...,
#         2.40870997e-01, 1.62807237e-02, 9.23176110e-03],
#        [1.64203748e-01, 8.49579349e-02, 8.42742505e-04, ...,
#         1.26757595e-05, 3.07490482e-05, 3.15266132e-01],
#        [4.61774645e-03, 4.00386658e-03, 2.95482352e-02, ...,
#         1.03110062e-04, 5.50522469e-04, 3.24757770e-04]], dtype=float32), array([[2.03824490e-02, 1.67230645e-03, 3.28308460e-03, ...,
#         1.21595897e-02, 3.65753584e-02, 5.86824317e-04],
#        [2.82408932e-04, 2.22162740e-07, 1.86388046e-04, ...,
#         3.34154338e-01, 2.85636797e-03, 4.03860431e-05],
#        [4.24237065e-02, 4.01532234e-05, 1.30740404e-02, ...,
#         5.39906323e-03, 4.73838568e-01, 1.76659357e-02],
#        ...,
#        [4.37680595e-02, 6.92549685e-04, 5.40805794e-03, ...,
#         2.40870997e-01, 1.62807237e-02, 9.23176110e-03],
#        [1.64203748e-01, 8.49579349e-02, 8.42742505e-04, ...,
#         1.26757595e-05, 3.07490482e-05, 3.15266132e-01],
#        [4.61774645e-03, 4.00386658e-03, 2.95482352e-02, ...,
#         1.03110062e-04, 5.50522469e-04, 3.24757770e-04]], dtype=float32), array([[2.03824490e-02, 1.67230645e-03, 3.28308460e-03, ...,
#         1.21595897e-02, 3.65753584e-02, 5.86824317e-04],
#        [2.82408932e-04, 2.22162740e-07, 1.86388046e-04, ...,
#         3.34154338e-01, 2.85636797e-03, 4.03860431e-05],
#        [4.24237065e-02, 4.01532234e-05, 1.30740404e-02, ...,
#         5.39906323e-03, 4.73838568e-01, 1.76659357e-02],
#        ...,
#        [4.37680595e-02, 6.92549685e-04, 5.40805794e-03, ...,
#         2.40870997e-01, 1.62807237e-02, 9.23176110e-03],
#        [1.64203748e-01, 8.49579349e-02, 8.42742505e-04, ...,
#         1.26757595e-05, 3.07490482e-05, 3.15266132e-01],
#        [4.61774645e-03, 4.00386658e-03, 2.95482352e-02, ...,
#         1.03110062e-04, 5.50522469e-04, 3.24757770e-04]], dtype=float32)]
# [array([[2.03824490e-02, 1.67230645e-03, 3.28308460e-03, ...,
#         1.21595897e-02, 3.65753584e-02, 5.86824317e-04],
#        [2.82408932e-04, 2.22162740e-07, 1.86388046e-04, ...,
#         3.34154338e-01, 2.85636797e-03, 4.03860431e-05],
#        [4.24237065e-02, 4.01532234e-05, 1.30740404e-02, ...,
#         5.39906323e-03, 4.73838568e-01, 1.76659357e-02],
#        ...,
#        [4.37680595e-02, 6.92549685e-04, 5.40805794e-03, ...,
#         2.40870997e-01, 1.62807237e-02, 9.23176110e-03],
#        [1.64203748e-01, 8.49579349e-02, 8.42742505e-04, ...,
#         1.26757595e-05, 3.07490482e-05, 3.15266132e-01],
#        [4.61774645e-03, 4.00386658e-03, 2.95482352e-02, ...,
#         1.03110062e-04, 5.50522469e-04, 3.24757770e-04]], dtype=float32), array([[2.03037057e-02, 2.05643126e-03, 3.55703081e-03, ...,
#         1.35733075e-02, 3.22181396e-02, 9.62973689e-04],
#        [1.36693576e-04, 2.36032506e-07, 5.49786855e-05, ...,
#         6.95712119e-02, 7.30281405e-04, 1.52710054e-04],
#        [5.26900440e-02, 3.31327283e-05, 4.57379082e-03, ...,
#         6.60537183e-03, 4.37291205e-01, 7.98423495e-03],
#        ...,
#        [6.10027499e-02, 8.02342605e-04, 3.53763299e-03, ...,
#         1.43236846e-01, 2.77701356e-02, 1.73082538e-02],
#         3.1751264e-05, 2.0181889e-05],
#        [1.2778259e-04, 2.1545512e-07, 4.0471642e-07, ..., 8.0737867e-05,
#         1.3257107e-03, 2.9070015e-04],
#        [9.9085504e-04, 4.5027650e-06, 3.4656427e-05, ..., 1.1917164e-04,
#         2.2823226e-02, 2.7728183e-03]], dtype=float32), array([[2.4328499e-04, 8.3925661e-10, 3.1956093e-10, ..., 6.7848637e-06,
#         1.2247922e-03, 1.4075003e-08],
#        [1.9393206e-06, 4.4079732e-10, 1.3762159e-09, ..., 4.3286641e-06,
#         2.8855804e-06, 7.1232193e-05],
#        [2.8146193e-03, 1.4850897e-05, 4.7592416e-06, ..., 1.6733578e-04,
#         3.4769052e-03, 3.4562332e-04],
#        ...,
#        [8.8281324e-04, 9.4637215e-08, 6.8803212e-09, ..., 4.0513765e-05,
#         2.4880215e-05, 6.0557254e-06],
#        [7.3545169e-05, 9.0074792e-07, 3.9120121e-07, ..., 2.3660102e-07,
#         1.7357837e-04, 6.2253739e-04],
#        [2.3091212e-03, 3.2978878e-06, 5.5842323e-04, ..., 3.8617671e-02,
#         1.1801212e-03, 9.7907818e-05]], dtype=float32), array([[6.7359756e-04, 4.1051740e-06, 2.3375098e-06, ..., 1.0546630e-04,
#         3.4420257e-03, 1.6817236e-03],
#        [1.4850070e-05, 9.6976244e-08, 2.4938359e-08, ..., 9.4393154e-06,
#         9.2864866e-06, 2.0785744e-03],
#        [1.7419588e-04, 9.0160537e-09, 1.7729072e-08, ..., 2.7948167e-06,
#         7.0772314e-04, 4.9440411e-04],
#        ...,
#        [2.1508636e-04, 7.8642913e-08, 8.9540708e-10, ..., 8.3382126e-08,
#         5.9565493e-05, 5.7771001e-03],
#        [3.1950269e-05, 9.5608899e-09, 1.6590831e-10, ..., 1.5441882e-08,
#         1.1168747e-04, 2.7166199e-04],
#        [7.2825234e-05, 2.5154912e-07, 1.7018971e-06, ..., 1.1858042e-04,
#         5.9245276e-04, 2.4292451e-04]], dtype=float32), array([[3.9083014e-05, 2.2592540e-07, 1.5048398e-09, ..., 2.2209907e-09,
#         2.1692646e-05, 1.8414455e-03],
#        [1.4432479e-04, 4.4333837e-07, 4.9942133e-07, ..., 2.8011396e-05,
#         6.9079862e-04, 1.2461690e-04],
#        [2.0744174e-05, 7.7713347e-09, 2.0024022e-09, ..., 5.9089183e-07,
#         2.1969502e-04, 7.9338970e-05],
#        ...,
#        [2.8867386e-03, 2.7736760e-07, 1.3554524e-08, ..., 4.5060533e-06,
#         3.8156915e-04, 3.8273393e-03],
#        [2.9395157e-04, 1.7581345e-07, 7.7828886e-08, ..., 3.7019367e-06,
#         2.0592280e-04, 4.7773561e-03],
#        [7.8031728e-05, 1.6715346e-08, 1.1922093e-07, ..., 2.0946757e-04,
#         2.2255855e-04, 1.3624849e-05]], dtype=float32), array([[2.2263327e-03, 1.6116861e-05, 2.7985839e-06, ..., 3.8037280e-05,
#         2.5074146e-04, 2.9291299e-03],
#        [7.5695956e-05, 4.4891095e-08, 2.2941643e-08, ..., 2.9645309e-05,
#         8.3504687e-04, 4.7328274e-05],
#        [4.0595472e-04, 1.3403481e-06, 1.5016594e-05, ..., 1.6136109e-04,
#         2.6770535e-05, 4.3562017e-03],
#        ...,
#        [3.7274527e-05, 1.2457486e-09, 1.3443748e-10, ..., 4.8471452e-07,
#         1.5713336e-04, 1.4751249e-06],
#        [2.5225116e-04, 1.0128828e-06, 7.4229874e-08, ..., 2.7534543e-05,
#         2.6663547e-04, 7.2275201e-04],
#        [6.2579522e-03, 5.3040392e-05, 2.9780387e-05, ..., 2.8715507e-04,
#         3.5250734e-04, 8.7760113e-02]], dtype=float32), array([[6.3675957e-06, 6.3201639e-08, 3.8084632e-08, ..., 7.1116352e-07,
#         1.0844735e-06, 4.2793234e-03],
#        [5.4186781e-05, 1.6456102e-08, 4.8315446e-08, ..., 2.9495408e-04,
#         3.3302107e-04, 1.6533681e-05],
#        [2.0452492e-06, 2.1385389e-10, 6.5675709e-09, ..., 1.9814965e-05,
#         4.3514858e-05, 5.8407704e-06],
#        ...,
#        [2.2236821e-04, 2.0197753e-08, 1.1862096e-09, ..., 7.6649858e-06,
#         5.0658459e-04, 1.7254461e-05],
#        [1.8311783e-05, 5.2364840e-07, 1.4792059e-07, ..., 9.2455036e-07,
#         2.4997717e-04, 8.7990117e-04],
#        [2.4538292e-04, 3.3652984e-08, 4.5027666e-09, ..., 2.9722657e-06,
#         1.2783556e-04, 2.1387929e-04]], dtype=float32), array([[3.42035200e-05, 2.82960940e-07, 3.61699151e-08, ...,
#         9.71215172e-07, 5.48747594e-05, 2.07527773e-04],
#        [5.53229984e-05, 6.00341355e-06, 4.45043042e-07, ...,
#         4.92757044e-06, 9.04202607e-05, 3.21721495e-03],
#        [3.63702893e-05, 1.59434421e-06, 2.42372181e-07, ...,
#         8.00339762e-07, 1.66664086e-06, 2.57631857e-03],
#        ...,
#        [6.03675609e-04, 8.62644299e-07, 1.19888693e-06, ...,
#         1.91001363e-05, 9.13915748e-04, 4.97506640e-04],
#        [1.15692406e-03, 8.30631564e-07, 1.91680624e-06, ...,
#         1.65619713e-04, 1.15983654e-04, 2.09388905e-03],
#        [6.34502769e-02, 2.91979144e-04, 7.33686466e-06, ...,
#         2.30130419e-04, 1.20826566e-03, 1.34844764e-03]], dtype=float32), array([[1.7579325e-05, 1.8363070e-07, 2.9242569e-08, ..., 5.0817857e-07,
#         5.7583798e-05, 5.0384778e-04],
#        [1.1010673e-03, 8.1310736e-06, 4.2463628e-07, ..., 3.6598991e-05,
#         1.2446642e-03, 3.8652648e-03],
#        [7.1605588e-03, 2.6145265e-06, 1.3384542e-07, ..., 7.7892457e-07,
#         3.7369167e-03, 1.0494018e-03],
#        ...,
#        [3.9636820e-05, 5.5766126e-08, 2.3442963e-08, ..., 8.6054652e-06,
#         3.7642592e-05, 6.8261550e-04],
#        [3.0862281e-04, 1.8269660e-06, 4.3014302e-06, ..., 1.8866059e-04,
#         4.3057723e-04, 7.1063917e-04],
#        [2.2761745e-04, 5.4313796e-07, 3.7182053e-07, ..., 7.0176233e-05,
#         5.8909305e-03, 2.0436865e-04]], dtype=float32)]
# [array([ 5, 27, 28, ..., 27, 29,  3]), array([ 5,  7, 28, ..., 27, 29,  3]), array([26,  7, 26, ..., 12, 29, 15]), array([ 5,  7, 26, ...,  8, 29, 15]), array([ 5,  7, 26, ..., 12, 29, 15]), array([12,  7,  8, ..., 24,  8, 15]), array([ 8,  7, 12, ...,  7,  8, 15]), array([ 8, 24, 26, ..., 21, 12, 24]), array([ 8,  8, 26, ..., 21, 21, 16]), array([12, 24,  8, ..., 12,  8, 24]), array([21, 24,  8, ..., 21,  8, 17]), array([21,  7, 12, ...,  8,  8, 12]), array([12, 24, 12, ..., 21, 12, 24]), array([12, 24, 12, ..., 12, 21, 24]), array([21, 24, 12, ..., 21, 21,  8]), array([21, 24, 12, ..., 24, 21, 24]), array([12,  7, 26, ..., 12, 12, 24]), array([21, 12, 24, ..., 12,  8, 12]), array([21,  8,  8, ..., 24, 24, 24]), array([21, 21, 21, ...,  8, 24, 24])]

# %%
import numpy as np
import matplotlib.pyplot as plt

# Assuming you have:
# y_pred_noisy_probs_list_1, y_pred_noisy_probs_list, y_reference_probs_list_1 (all lists of arrays of shape (samples, num_classes))
# and stddev_values (length 20)

rrl_values = []

for pred_noisy_1, pred_noisy, ref_probs in zip(y_pred_noisy_probs_list_1, y_pred_noisy_probs_list, y_reference_probs_list_1):
    # Compute numerator: l2 norm squared between pred_noisy_1 and ref_probs
    numerator = np.linalg.norm(pred_noisy_1 - ref_probs) ** 2

    # Compute denominator: l2 norm squared between pred_noisy and ref_probs
    denominator = np.linalg.norm(pred_noisy - ref_probs) ** 2

    # Compute RRL value
    rrl = numerator / denominator if denominator != 0 else np.nan
    rrl_values.append(rrl)

# Plot RRL vs Standard Deviation
plt.figure(figsize=(8, 5))
plt.plot(stddev_values, rrl_values, marker='o')
plt.xlabel('Standard Deviation of Gaussian Noise')
plt.ylabel('RRL Value')
plt.title('RRL vs Noise Standard Deviation')
plt.grid(True)
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# Assuming you have:
# y_pred_noisy_probs_list_1, y_pred_noisy_probs_list, y_reference_probs_list_1 (all lists of arrays of shape (samples, num_classes))
# and stddev_values (length 20)

rrl_values = []

for pred_noisy_1, pred_noisy, ref_probs in zip(y_pred_noisy_probs_list_1, y_pred_noisy_probs_list, y_reference_probs_list_1):
    # Compute numerator: l2 norm squared between pred_noisy_1 and ref_probs
    numerator = np.linalg.norm(pred_noisy_1 - ref_probs) ** 2

    # Compute denominator: l2 norm squared between pred_noisy and ref_probs
    denominator = np.linalg.norm(pred_noisy - ref_probs) ** 2

    # Compute RRL value
    rrl = numerator / denominator if denominator != 0 else np.nan
    rrl_values.append(rrl)

# Plot RRL vs Standard Deviation
fig = plt.figure(figsize=(8, 5))
plt.plot(stddev_values, rrl_values, marker='o')
plt.xlabel('Standard Deviation of Gaussian Noise')
plt.ylabel('RRL Value')
plt.title('RRL vs Noise Standard Deviation')
plt.grid(True)

# Save the figure as PDF before showing
fig.savefig('rrl_vs_noise_AIDS.pdf')

# Show the plot
plt.show()
